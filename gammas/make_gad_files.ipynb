# %%
import pandas as pd

# %%
rdrive = '/mnt/researchdrive/BOX_INTERNAL/opotowsky/'

lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']
nuc_list = ['ac227', 'am241', 'am243', 'ba133', 'cf249', 'cf252', 'cm243', 'cm244', 
            'cm245', 'cs134', 'cs137', 'eu152', 'eu154', 'ho166m', 'kr85', 'nb94', 
            'np236', 'np237', 'pa231', 'pm146', 'pu236', 'pu238', 'pu239', 'pu240', 
            'ra226', 'sb125', 'th228', 'th229', 'u232', 'u233', 'u234', 'u235']

# %%
db = pd.read_pickle(rdrive + 'nuc32_activities_scaled_1g_reindex.pkl')

# %%
# Source age needs to be above but close to zero because these activities are pre-decayed.
# study is in a directory in gadras detector response repo
# the below time is 20 min
db['Age'] = 3.805175e-5 
db.head()
# Out:
#   ReactorType  CoolingTime  Enrichment   Burnup OrigenReactor  \
# 0         bwr     0.474492         0.5  1015.52       ge7x7-0
# 1         bwr     0.730482         0.5  1015.52       ge7x7-0
# 2         bwr     5.169458         0.5  1015.52       ge7x7-0
# 3         bwr    38.224741         0.5  1015.52       ge7x7-0
# 4         bwr    81.132547         0.5  1015.52       ge7x7-0
#
#    AvgPowerDensity  ModDensity  UiWeight         ac227         am241  ...  \
# 0             10.0         0.1         1  1.357000e-15  2.693000e-07  ...
# 1             10.0         0.1         1  1.366000e-15  2.720000e-07  ...
# 2             10.0         0.1         1  1.516000e-15  3.178000e-07  ...
# 3             10.0         0.1         1  2.670000e-15  6.579000e-07  ...
# 4             10.0         0.1         1  4.239000e-15  1.097000e-06  ...
#
#       pu240         ra226     sb125         th228         th229          u232  \
# 0  0.000028  3.293000e-16  0.000391  2.903000e-13  2.451000e-16  1.089000e-11
# 1  0.000028  3.309000e-16  0.000391  2.930000e-13  2.453000e-16  1.095000e-11
# 2  0.000028  3.600000e-16  0.000398  3.410000e-13  2.489000e-16  1.137000e-11
# 3  0.000028  6.155000e-16  0.000408  7.103000e-13  2.754000e-16  1.215000e-11
# 4  0.000028  1.050000e-15  0.000398  1.207000e-12  3.098000e-16  1.310000e-11
#
#            u233      u234          u235       Age
# 0  3.101000e-12  0.000002  9.171000e-09  0.000038
# 1  3.101000e-12  0.000002  9.171000e-09  0.000038
# 2  3.101000e-12  0.000002  9.171000e-09  0.000038
# 3  3.104000e-12  0.000002  9.171000e-09  0.000038
# 4  3.107000e-12  0.000002  9.171000e-09  0.000038
#
# [5 rows x 41 columns]

# %%
db = db[['Age'] + nuc_list]
db.head()
# Out:
#         Age         ac227         am241         am243         ba133  \
# 0  0.000038  1.357000e-15  2.693000e-07  2.450000e-09  7.245000e-13
# 1  0.000038  1.366000e-15  2.720000e-07  2.454000e-09  7.245000e-13
# 2  0.000038  1.516000e-15  3.178000e-07  2.457000e-09  7.239000e-13
# 3  0.000038  2.670000e-15  6.579000e-07  2.457000e-09  7.196000e-13
# 4  0.000038  4.239000e-15  1.097000e-06  2.457000e-09  7.141000e-13
#
#           cf249         cf252         cm243         cm244         cm245  ...  \
# 0  4.657000e-24  1.370000e-23  4.937000e-10  2.395000e-08  2.491000e-13  ...
# 1  4.794000e-24  1.369000e-23  4.937000e-10  2.395000e-08  2.491000e-13  ...
# 2  7.155000e-24  1.365000e-23  4.936000e-10  2.396000e-08  2.491000e-13  ...
# 3  2.404000e-23  1.333000e-23  4.925000e-10  2.388000e-08  2.491000e-13  ...
# 4  4.422000e-23  1.293000e-23  4.911000e-10  2.377000e-08  2.491000e-13  ...
#
#       pu239     pu240         ra226     sb125         th228         th229  \
# 0  0.000083  0.000028  3.293000e-16  0.000391  2.903000e-13  2.451000e-16
# 1  0.000083  0.000028  3.309000e-16  0.000391  2.930000e-13  2.453000e-16
# 2  0.000086  0.000028  3.600000e-16  0.000398  3.410000e-13  2.489000e-16
# 3  0.000087  0.000028  6.155000e-16  0.000408  7.103000e-13  2.754000e-16
# 4  0.000087  0.000028  1.050000e-15  0.000398  1.207000e-12  3.098000e-16
#
#            u232          u233      u234          u235
# 0  1.089000e-11  3.101000e-12  0.000002  9.171000e-09
# 1  1.095000e-11  3.101000e-12  0.000002  9.171000e-09
# 2  1.137000e-11  3.101000e-12  0.000002  9.171000e-09
# 3  1.215000e-11  3.104000e-12  0.000002  9.171000e-09
# 4  1.310000e-11  3.107000e-12  0.000002  9.171000e-09
#
# [5 rows x 33 columns]

# %%
db.to_csv(rdrive + 'nuc32.act', sep = ' ', header=False)

# %%
minidb = db.sample(150)
minidb.reset_index(drop=True, inplace=True)
minidb

# %%
#minidb.to_csv('test2row.act', sep = ' ', header=False)
minidb.to_csv('test150row.act', sep = ' ', header=False)

# %%
with open('NucNameList.txt', 'w') as f:
    for nuc in nuc_list:
        gadnuc = nuc[0].upper() + nuc[1:]
        f.write(gadnuc + '\n')
