# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from heatmap import heatmap, corrplot
# %matplotlib inline

# %%
rdrive = '/mnt/researchdrive/BOX_INTERNAL/opotowsky/'

# %%
nuc29_path = rdrive + 'sim_grams_nuc29.pkl'
nuc29 = pd.read_pickle(nuc29_path)

# %%
lbls = ['AvgPowerDensity', 'Burnup', 'CoolingTime', 'Enrichment', 'ModDensity',
        'OrigenReactor', 'ReactorType', 'UiWeight']
nucs = nuc29.columns.drop(lbls).to_list()

# %%
columns = nucs
corr = nuc29[columns].corr()

# %%
fig, ax = plt.subplots(figsize=(10,10))
corrplot(corr, size_scale=150, marker='s')

# %%
df = pd.read_pickle(rdrive + 'nuc32_activities_scaled_1g_reindex.pkl')
nucs = df.columns.drop(lbls).to_list()
columns = nucs
corr = df[columns].corr()

# %%
fig, ax = plt.subplots(figsize=(10,10))
corrplot(corr, size_scale=150, marker='s')

# %%
df = pd.read_pickle(rdrive + 'nuc12_activities_scaled_1g_reindex.pkl')
nucs = df.columns.drop(lbls).to_list()
columns = nucs
corr = df[columns].corr()

# %%
fig, ax = plt.subplots(figsize=(10,10))
corrplot(corr, size_scale=500, marker='s')
