# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Data Setup & Functions

# %%
from mll_calc.mll_pred import format_XY
from mll_calc.all_jobs import uncs, job_dirs

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

# %%
def loop_db(XY, pred, unc, lbls, nonlbls):  
    logpdf_df = pd.DataFrame()
    for idx, row in pred.iterrows():
        sim_idx = row['sim_idx']
        pred_idx = row['pred_idx']
        all_lbls = lbls + nonlbls
        
        test_sample = XY.loc[sim_idx].drop(all_lbls)
        train_row = XY.loc[pred_idx].drop(all_lbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = row['MaxLogLL']
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=sim_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %% [markdown]
# ### Train and Test DBs

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

rdrive = '/mnt/researchdrive/BOX_INTERNAL/opotowsky/'
train_pkl = 'detector_response/d1_hpge_spectra_peaks_trainset.pkl'
XY = format_XY(rdrive + train_pkl)

# %% [markdown]
# ### LL Calc Results

# %%
results = rdrive + 'mll/gam_spec/d1/'

dfs = {}
for i, job in enumerate(job_dirs):
    key = 'unc' + str(i)
    dfs[key] = pd.read_csv(results + job + '/' + job + '.csv').drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
    dfs[key]['Relative_Burnup_Error'] = dfs[key]['Burnup_Error'] / dfs[key]['Burnup']
    dfs[key]['Relative_Enrichment_Error'] = dfs[key]['Enrichment_Error'] / dfs[key]['Enrichment']
    dfs[key]['Relative_CoolingTime_Error'] = dfs[key]['CoolingTime_Error'] / dfs[key]['CoolingTime']

# %%
# For ease of only viewing 5% case for now
preds = dfs['unc0']

# %%
preds.columns
# Out:
# Index(['Unnamed: 0.1.1', 'sim_idx', 'ReactorType', 'CoolingTime', 'Enrichment',
#        'Burnup', 'OrigenReactor', 'AvgPowerDensity', 'ModDensity', 'UiWeight',
#        'pred_idx', 'pred_ReactorType', 'pred_CoolingTime', 'pred_Enrichment',
#        'pred_Burnup', 'pred_OrigenReactor', 'pred_AvgPowerDensity',
#        'pred_ModDensity', 'pred_UiWeight', 'MaxLogLL', 'MaxLLUnc',
#        '2ndMaxLogLL', '2ndMaxLLUnc', 'CDF_LogLL_0.9998', 'CDF_LLUnc_0.9998',
#        'CDF_LogLL_0.9988', 'CDF_LLUnc_0.9988', 'CDF_LogLL_0.95',
#        'CDF_LLUnc_0.95', 'CDF_LogLL_0.9', 'CDF_LLUnc_0.9', 'CDF_LogLL_0.5',
#        'CDF_LLUnc_0.5', 'CDF_LogLL_0.1', 'CDF_LLUnc_0.1', 'CDF_LogLL_0.01',
#        'CDF_LLUnc_0.01', 'ReactorType_Score', 'CoolingTime_Error',
#        'Enrichment_Error', 'Burnup_Error', 'OrigenReactor_Score',
#        'Relative_Burnup_Error', 'Relative_Enrichment_Error',
#        'Relative_CoolingTime_Error'],
#       dtype='object')

# %% [markdown]
# ### LogPDF (wrt nuclide) results

# %%
unc = 0.05
#logpdf_df = loop_db(XY, preds, unc, lbls, nonlbls)

# %% [markdown]
# # Explore Errors

# %% [markdown]
# ### Burnup

# %%
preds['Burnup_Error'].describe()
# Out:
# count    24080.000000
# mean       283.350105
# std        800.097291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        160.020000
# max      13514.130000
# Name: Burnup_Error, dtype: float64

# %%
preds['Relative_Burnup_Error'].describe()
# nuc29 results for comparison
#count    24030.000000
#mean         0.003469
#std          0.009906
#min          0.000000
#25%          0.000000
#50%          0.000000
#75%          0.000000
#max          0.141558
# Out:
# count    24080.000000
# mean         0.007434
# std          0.016869
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.007890
# max          0.303447
# Name: Relative_Burnup_Error, dtype: float64

# %%
to_print = ['sim_idx', 'pred_idx', 'MaxLogLL',
            'AvgPowerDensity', 'pred_AvgPowerDensity', 
            'ModDensity', 'pred_ModDensity',
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Relative_Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Relative_Burnup_Error',
            'CoolingTime', 'pred_CoolingTime', 'Relative_CoolingTime_Error',
            'OrigenReactor', 'pred_OrigenReactor']
preds.loc[preds['Relative_Burnup_Error'] > 0.16, to_print]
# Out:
#        sim_idx  pred_idx     MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 3224     58941    169743 -1418.153153             22.0                  10.0
# 4169     76287    389164 -1136.624763             10.0                  35.0
# 4260     78057    147382 -1229.279927             22.0                  22.0
# 4432     81125    439768 -1152.840902             22.0                  18.0
# 4484     82069    427042 -1436.745868             22.0                  35.0
# 8282    151630    272403 -1448.481905             22.0                  10.0
# 12118   221663    266208 -1145.686783             10.0                  22.0
# 13487   246738    328689 -1347.126888             22.0                  25.0
# 13709   250750    365033 -1462.136763             22.0                  41.0
# 16771   306918     47672 -1447.299418             22.0                  10.0
# 17165   314116    127381 -1091.392116             10.0                  22.0
# 18433   337303    369458 -1300.382746             35.0                  25.0
# 19198   351227    158120 -1408.904073             25.0                  22.0
# 21410   391878    303142 -1355.191304             25.0                  22.0
# 22427   410286     51625 -1250.132469             25.0                  22.0
# 22743   416197     84199 -1451.503034             35.0                  10.0
# 23283   426109     31338 -1438.228744             25.0                  10.0
#
#        ModDensity  pred_ModDensity ReactorType pred_ReactorType  \
# 3224         0.30             0.70         bwr              bwr
# 4169         0.70             0.71         bwr              pwr
# 4260         0.70             0.10         bwr              bwr
# 4432         0.10             0.84         bwr             phwr
# 4484         0.10             0.71         bwr              pwr
# 8282         0.30             0.50         bwr              bwr
# 12118        0.70             0.10         bwr              bwr
# 13487        0.50             0.71         bwr              pwr
# 13709        0.70             0.71         bwr              pwr
# 16771        0.10             0.50         bwr              bwr
# 17165        0.70             0.50         bwr              bwr
# 18433        0.71             0.71         pwr              pwr
# 19198        0.71             0.70         pwr              bwr
# 21410        0.71             0.70         pwr              bwr
# 22427        0.71             0.70         pwr              bwr
# 22743        0.71             0.30         pwr              bwr
# 23283        0.71             0.30         pwr              bwr
#
#        ReactorType_Score  ...  pred_Enrichment  Relative_Enrichment_Error  \
# 3224                True  ...            0.510                   0.875306
# 4169               False  ...            1.610                   0.678000
# 4260                True  ...            4.760                   0.048000
# 4432               False  ...            0.711                   0.422000
# 4484               False  ...            5.270                   9.540000
# 8282                True  ...            2.200                   0.537815
# 12118               True  ...            2.200                   0.456790
# 13487              False  ...            3.220                   5.440000
# 13709              False  ...            0.500                   0.000000
# 16771               True  ...            2.790                   0.413866
# 17165               True  ...            2.790                   0.413866
# 18433               True  ...            2.030                   0.611111
# 19198              False  ...            4.760                   0.597315
# 21410              False  ...            3.800                   0.890547
# 22427              False  ...            2.790                   0.897959
# 22743              False  ...            0.500                   0.735450
# 23283              False  ...            2.190                   0.584440
#
#          Burnup  pred_Burnup  Relative_Burnup_Error  CoolingTime  \
# 3224   36277.08     42615.19               0.174714     0.000576
# 4169    7973.46      5634.20               0.293381     0.000576
# 4260   11457.98      9547.88               0.166705     0.000576
# 4432    4878.84      6153.14               0.261189     0.000772
# 4484   36282.93     42293.67               0.165663     0.000772
# 8282   47192.85     59719.48               0.265435     0.000772
# 12118   7853.16      5844.07               0.255832     0.000521
# 13487  15730.18     19747.80               0.255408     0.000751
# 13709  44535.37     36875.71               0.171990     0.000751
# 16771  44535.37     58049.50               0.303447     0.000751
# 17165   5844.07      4878.84               0.165164     0.000751
# 18433  15311.24     12720.07               0.169233     0.000548
# 19198  31963.35     37576.78               0.175621     0.000875
# 21410  19175.59     23069.56               0.203069     0.000864
# 22427   9833.56     11457.98               0.165191     0.000670
# 22743  60288.68     70500.00               0.169374   823.657134
# 23283  60288.68     70500.00               0.169374   823.657134
#
#        pred_CoolingTime  Relative_CoolingTime_Error  OrigenReactor  \
# 3224           0.000521                    0.095486        ge7x7-0
# 4169           0.000864                    0.500000        ge7x7-0
# 4260           0.000772                    0.340278        ge7x7-0
# 4432           0.000591                    0.234456       abb8x8-1
# 4484           0.000670                    0.132124       abb8x8-1
# 8282           0.000751                    0.027202       abb8x8-1
# 12118          0.000751                    0.441459  atrium10x10-9
# 13487          0.000548                    0.270306       svea64-1
# 13709          0.000728                    0.030626       svea64-1
# 16771          0.000576                    0.233023       svea64-1
# 17165          0.000772                    0.027963       svea64-1
# 18433          0.000728                    0.328467        ce14x14
# 19198          0.000772                    0.117714         w17x17
# 21410          0.000751                    0.130787        bw15x15
# 22427          0.000576                    0.140299       vver1000
# 22743        211.644821                    0.743043       vver1000
# 23283        601.367719                    0.269881       vver1000
#
#       pred_OrigenReactor
# 3224       atrium10x10-9
# 4169             bw15x15
# 4260            abb8x8-1
# 4432             candu37
# 4484            vver1000
# 8282            svea64-1
# 12118           svea64-1
# 13487            ce14x14
# 13709             s18x18
# 16771            ge7x7-0
# 17165           abb8x8-1
# 18433             s18x18
# 19198           abb8x8-1
# 21410           svea64-1
# 22427            ge7x7-0
# 22743           abb8x8-1
# 23283            ge7x7-0
#
# [17 rows x 21 columns]

# %%
# finding a good prediction with high Max LL
new_df = preds.loc[(preds['Relative_Burnup_Error'] == 0.0) & 
                   (preds['Relative_Enrichment_Error'] == 0.0) & 
                   (preds['Relative_CoolingTime_Error'] == 0.0) & 
                   (preds['ReactorType_Score'] == True) &
                   (preds['MaxLogLL'] > 20), to_print]
new_df

# %%
new_df.iloc[0:1].to_pickle('train_pred_good.pkl')

# %%
# finding a bad prediction
new_df = preds.loc[(preds['Relative_Burnup_Error'] > 0.05) & 
                   (preds['Relative_Enrichment_Error'] > 0.05) & 
                   (preds['Relative_CoolingTime_Error'] != np.inf) & (preds['Relative_CoolingTime_Error'] > 0.05) &
                   (preds['ReactorType_Score'] == False), to_print]
                   #(preds['MaxLogLL'] > 20)
new_df

# %%
new_df.iloc[0:1].to_pickle('train_pred_bad.pkl')

# %% [markdown]
# ### Enrichment

# %%
preds['Enrichment_Error'].describe()
# Out:
# count    24080.000000
# mean         0.474577
# std          0.707389
# min          0.000000
# 25%          0.000000
# 50%          0.040000
# 75%          0.810000
# max          4.820000
# Name: Enrichment_Error, dtype: float64

# %%
preds['Relative_Enrichment_Error'].describe()
# nuc29 results for comparison
#count    24030.000000
#mean         0.003688
#std          0.015824
#min          0.000000
#25%          0.000000
#50%          0.000000
#75%          0.000000
#max          0.260204
# Out:
# count    24080.000000
# mean         0.252097
# std          0.637707
# min          0.000000
# 25%          0.000000
# 50%          0.038462
# 75%          0.272727
# max          9.640000
# Name: Relative_Enrichment_Error, dtype: float64

# %%
preds.loc[preds['Enrichment_Error'] > 4, to_print]
# Out:
#        sim_idx  pred_idx     MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 66        1191    227457 -1389.293601             10.0                  22.0
# 156       2783    306748 -1406.768224             22.0                  22.0
# 257       4610     77296 -1413.447099             10.0                  10.0
# 327       5997     67114 -1272.340226             22.0                  10.0
# 606      11160    425753 -1395.346369             10.0                  25.0
# 684      12477    147878 -1286.260930             22.0                  22.0
# 3853     70575    163090 -1379.131373             10.0                  10.0
# 4310     78915     11241 -1312.374052             22.0                  10.0
# 4410     80727    336730 -1392.146744             10.0                  25.0
# 4484     82069    427042 -1436.745868             22.0                  35.0
# 4654     85236    306545 -1259.400094             22.0                  22.0
# 4843     88745    339021 -1403.271265             22.0                  41.0
# 4921     90109    146275 -1318.063964             10.0                  10.0
# 4930     90340    381033 -1378.006050             10.0                  25.0
# 4944     90472    237380 -1321.196282             10.0                  22.0
# 4948     90455    154764 -1395.324087             10.0                  22.0
# 5015     91731    146243 -1208.489269             22.0                  10.0
# 8007    146455    239030 -1339.824514             10.0                  10.0
# 8087    148035    166203 -1405.611583             22.0                  10.0
# 8090    148214     80540 -1422.701179             22.0                  10.0
# 8456    154764     90455 -1395.605206             22.0                  10.0
# 8461    154833    248998 -1366.589669             22.0                  10.0
# 8757    160196    338084 -1422.055146             10.0                  35.0
# 8905    163021    306687 -1418.013361             10.0                  22.0
# 9011    164919    316902 -1406.126938             22.0                  22.0
# 9019    164941    337928 -1332.906656             22.0                  35.0
# 9181    168134    316751 -1299.999406             22.0                  22.0
# 9260    169573    232344 -1394.427425             10.0                  10.0
# 9279    169690    151459 -1413.508045             10.0                  22.0
# 9362    171351    428234 -1379.219263             22.0                  41.0
# 12329   225564     90102 -1346.946211             10.0                  10.0
# 12337   225696    161275 -1317.221885             10.0                  22.0
# 12973   237429    245808 -1379.070461             22.0                  10.0
# 13247   242391    235779 -1360.975049             10.0                  10.0
# 17313        739.602688                    0.741710       svea64-1
# 17322        540.893339                    0.325821       svea64-1
# 17361       1681.646937                    0.134847        ce14x14
# 17362       1384.544304                    0.165996        ce14x14
# 18389        926.334688                    0.773707        ce14x14
# 19674        792.107142                    0.532078         w17x17
# 19736        424.641652                    1.281335         w17x17
# 19941        601.367719                    0.498159         s18x18
# 20827          0.000751                    0.031593         s18x18
# 21098       1054.187661                    0.238603        bw15x15
#
#       pred_OrigenReactor
# 66         atrium10x10-9
# 156             svea64-1
# 257              ge7x7-0
# 327              ge7x7-0
# 606             vver1000
# 684             abb8x8-1
# 3853       atrium10x10-9
# 4310             ge7x7-0
# 4410             ce14x14
# 4484            vver1000
# 4654            svea64-1
# 4843             ce14x14
# 4921            abb8x8-1
# 4930              s18x18
# 4944       atrium10x10-9
# 4948            abb8x8-1
# 5015            abb8x8-1
# 8007            svea64-1
# 8087       atrium10x10-9
# 8090            abb8x8-1
# 8456            abb8x8-1
# 8461            svea64-1
# 8757             ce14x14
# 8905            svea64-1
# 9011            svea64-1
# 9019             ce14x14
# 9181            svea64-1
# 9260       atrium10x10-9
# 9279            abb8x8-1
# 9362            vver1000
# 12329           abb8x8-1
# 12337      atrium10x10-9
# 12973           svea64-1
# 13247      atrium10x10-9
# 13607      atrium10x10-9
# 13693           svea64-1
# 16743           abb8x8-1
# 16744             w17x17
# 16763      atrium10x10-9
# 16953      atrium10x10-9
# 17313      atrium10x10-9
# 17322           svea64-1
# 17361            bw15x15
# 17362            bw15x15
# 18389            ce14x14
# 19674            ge7x7-0
# 19736           svea64-1
# 19941            ge7x7-0
# 20827           svea64-1
# 21098            bw15x15
#
# [50 rows x 21 columns]

# %% [markdown]
# ### Cooling Time

# %%
preds['CoolingTime_Error'].describe()
# Out:
# count    24080.000000
# mean        65.774197
# std        106.819106
# min          0.000000
# 25%          0.837097
# 50%         22.985977
# 75%         78.118430
# max       1047.926663
# Name: CoolingTime_Error, dtype: float64

# %%
preds['Relative_CoolingTime_Error'].describe()
# nuc29 results for comparison
#count    2.402900e+04
#mean              inf
#std               NaN
#min      0.000000e+00
#25%      3.174909e-03
#50%      1.037382e-02
#75%      2.831056e-02
#max               inf
# Out:
# count    24080.000000
# mean        12.437931
# std        282.437788
# min          0.000000
# 25%          0.000711
# 50%          0.012022
# 75%          0.066165
# max      12168.499040
# Name: Relative_CoolingTime_Error, dtype: float64

# %%
preds.loc[preds['CoolingTime_Error'] > 800, to_print]
#preds.loc[(preds['Relative_CoolingTime_Error'] != np.inf) & (preds['Relative_CoolingTime_Error'] > 5000), to_print]
# Out:
#        sim_idx  pred_idx     MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 4039     73901    372508 -1301.021185             10.0                  41.0
# 17030   311684    368685 -1255.359471             10.0                  41.0
# 17032   311681    389741 -1273.777232             10.0                  35.0
# 17225   315221    393635 -1295.915947             10.0                  35.0
# 23926   437888    384164 -1104.838749              2.2                  25.0
# 23951   438452     11964 -1079.148043              2.2                  22.0
# 23959   438439     10301 -1112.470551              2.2                  10.0
# 23983   438890    172354 -1261.732106              2.2                  10.0
# 23988   438876    170686 -1105.115589              2.2                  22.0
#
#        ModDensity  pred_ModDensity ReactorType pred_ReactorType  \
# 4039         0.50             0.71         bwr              pwr
# 17030        0.50             0.71         bwr              pwr
# 17032        0.50             0.71         bwr              pwr
# 17225        0.70             0.71         bwr              pwr
# 23926        0.84             0.71        phwr              pwr
# 23951        0.84             0.70        phwr              bwr
# 23959        0.84             0.70        phwr              bwr
# 23983        0.84             0.10        phwr              bwr
# 23988        0.84             0.70        phwr              bwr
#
#        ReactorType_Score  ...  pred_Enrichment  Relative_Enrichment_Error  \
# 4039               False  ...             2.03                   0.594000
# 17030              False  ...             1.61                   0.661765
# 17032              False  ...             1.61                   0.661765
# 17225              False  ...             2.01                   0.577731
# 23926              False  ...             0.50                   0.296765
# 23951              False  ...             0.54                   0.240506
# 23959              False  ...             0.54                   0.240506
# 23983              False  ...             1.44                   1.025316
# 23988              False  ...             0.51                   0.282700
#
#          Burnup  pred_Burnup  Relative_Burnup_Error  CoolingTime  \
# 4039   38404.38     36875.71               0.039805  3069.556073
# 17030  34542.92     33606.05               0.027122  4609.418475
# 17032  34542.92     33455.37               0.031484  3828.034825
# 17225  44535.37     42528.45               0.045064  3828.034825
# 23926   4529.76      4289.02               0.053146   377.951895
# 23951   8649.45      8232.51               0.048204  3968.955180
# 23959   8649.45      8232.51               0.048204  2478.741403
# 23983  13667.64     12861.21               0.059003   290.765745
# 23988  12861.88     11583.12               0.099422  5744.043580
#
#        pred_CoolingTime  Relative_CoolingTime_Error  OrigenReactor  \
# 4039        3889.809512                    0.267222        ge7x7-0
# 17030       5477.170170                    0.188256       svea64-1
# 17032       4659.404299                    0.217179       svea64-1
# 17225       4659.404299                    0.217179       svea64-1
# 23926       1178.272577                    2.117520        candu37
# 23951       4888.970123                    0.231803        candu37
# 23959       3317.028212                    0.338191        candu37
# 23983       1222.842911                    3.205595        candu37
# 23988       6791.970243                    0.182437        candu37
#
#       pred_OrigenReactor
# 4039              s18x18
# 17030             s18x18
# 17032            bw15x15
# 17225            bw15x15
# 23926            bw15x15
# 23951            ge7x7-0
# 23959            ge7x7-0
# 23983      atrium10x10-9
# 23988      atrium10x10-9
#
# [9 rows x 21 columns]

# %% [markdown]
# # Max Log LL

# %%
print(dfs['unc0']['MaxLogLL'].describe())
print(dfs['unc1']['MaxLogLL'].describe())
print(dfs['unc2']['MaxLogLL'].describe())
print(dfs['unc3']['MaxLogLL'].describe())
# Out:
# count    24080.000000
# mean     -1226.388858
# std        159.236910
# min      -1554.191596
# 25%      -1332.813917
# 50%      -1271.165489
# 75%      -1142.566049
# max       -592.383835
# Name: MaxLogLL, dtype: float64
# count    24080.000000
# mean     -1304.233124
# std        158.340699
# min      -1597.782884
# 25%      -1409.295233
# 50%      -1348.834613
# 75%      -1221.243084
# max       -685.392542
# Name: MaxLogLL, dtype: float64
# count    24080.000000
# mean     -1349.304149
# std        159.145652
# min      -1644.400756
# 25%      -1455.144632
# 50%      -1392.957910
# 75%      -1267.006359
# max       -727.760277
# Name: MaxLogLL, dtype: float64
# count    24080.000000
# mean     -1380.682951
# std        158.856992
# min      -1676.538345
# 25%      -1485.146805
# 50%      -1424.772146
# 75%      -1297.925444
# max       -766.830634
# Name: MaxLogLL, dtype: float64
