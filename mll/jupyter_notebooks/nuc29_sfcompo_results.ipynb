# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Data Setup & Functions

# %%
from mll_calc.mll_pred import format_XY, convert_g_to_mgUi

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

# %%
def loop_sfco(XY, test, pred, unc, lbls, nonlbls):
    xy_cols = XY.columns.tolist()
    for col in nonlbls: xy_cols.remove(col)
    test = test[xy_cols]
    
    logpdf_df = pd.DataFrame()
    for test_idx, row in test.iterrows():
        test_sample = row.drop(lbls)
        test_answer = row[lbls]
        pred_row = pred.loc[pred['sim_idx'] == test_idx]
        pred_idx = pred_row['pred_idx'].values[0]
        train_row = XY.loc[pred_idx].drop(lbls+nonlbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = pred_row['MaxLogLL'].values[0]
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=test_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %% [markdown]
# ### Train and Test DBs

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

train_pkl = '~/sims_n_results/final_sims_nov2020/not-scaled_nuc29.pkl'
XY = format_XY(train_pkl)
XY = convert_g_to_mgUi(XY, lbls+nonlbls)

sfco_pkl = '~/sfcompo/format_clean/sfcompo_nuc29.pkl'
sfco = pd.read_pickle(sfco_pkl)

# %% [markdown]
# ### LL Calc Results

# %%
sfcompo_results = '~/sims_n_results/final_sims_nov2020/mll/sfco/'

uncs = [0.05, 0.1, 0.15, 0.2]
job_dirs = ['Job' + str(i) + '_unc' + str(unc) for i, unc in enumerate(uncs)]
dfs = {}
for i, unc_job in enumerate(job_dirs):
    dfs['unc' + str(i)] = pd.read_csv(sfcompo_results + unc_job + '/' + unc_job + '.csv')

for dfname in list(dfs.keys()):
    df = dfs[dfname]
    df['Relative_Burnup_Error'] = df['Burnup_Error'] / df['Burnup']
    df['Relative_Enrichment_Error'] = df['Enrichment_Error'] / df['Enrichment']

# For ease of only viewing 5% case for now
preds = dfs['unc0']

# %%
preds.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'sim_idx', 'ReactorType', 'CoolingTime',
#        'Enrichment', 'Burnup', 'OrigenReactor', 'pred_idx', 'pred_ReactorType',
#        'pred_CoolingTime', 'pred_Enrichment', 'pred_Burnup',
#        'pred_OrigenReactor', 'pred_AvgPowerDensity', 'pred_ModDensity',
#        'pred_UiWeight', 'MaxLogLL', 'MaxLLUnc', '2ndMaxLogLL', '2ndMaxLLUnc',
#        'CDF_LogLL_0.9998', 'CDF_LLUnc_0.9998', 'CDF_LogLL_0.9988',
#        'CDF_LLUnc_0.9988', 'CDF_LogLL_0.95', 'CDF_LLUnc_0.95', 'CDF_LogLL_0.9',
#        'CDF_LLUnc_0.9', 'CDF_LogLL_0.5', 'CDF_LLUnc_0.5', 'CDF_LogLL_0.1',
#        'CDF_LLUnc_0.1', 'CDF_LogLL_0.01', 'CDF_LLUnc_0.01',
#        'ReactorType_Score', 'CoolingTime_Error', 'Enrichment_Error',
#        'Burnup_Error', 'OrigenReactor_Score', 'Relative_Burnup_Error',
#        'Relative_Enrichment_Error'],
#       dtype='object')

# %% [markdown]
# ### LogPDF (wrt nuclide) results

# %%
unc = 0.05
logpdf_df = loop_sfco(XY, sfco, preds, unc, lbls, nonlbls)

# %% [markdown]
# # Explore Errors

# %% [markdown]
# ### Burnup

# %%
preds['Relative_Burnup_Error'].describe()
# old nuc29 results for reference:
#count    505.000000
#mean       0.151887
#std        0.195778
#min        0.000031
#25%        0.036301
#50%        0.087295
#75%        0.183161
#max        1.440513
# Out:
# count    505.000000
# mean       0.132149
# std        0.150509
# min        0.000104
# 25%        0.031564
# 50%        0.077272
# 75%        0.184942
# max        0.958580
# Name: Relative_Burnup_Error, dtype: float64

# %%
to_print = ['sim_idx', 'pred_idx', 'MaxLogLL',
            'pred_AvgPowerDensity', 'pred_ModDensity', 'pred_CoolingTime',
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Relative_Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Relative_Burnup_Error',
            'OrigenReactor', 'pred_OrigenReactor']
preds.loc[preds['Relative_Burnup_Error'] > 0.49, to_print]
# Out:
#                  sim_idx  pred_idx    MaxLogLL  pred_AvgPowerDensity  \
# 54     GAR-1|SA-13|E6|11     84260   12.026430                  10.0
# 57     GAR-1|SA-13|E6|16    386831   -1.338533                  10.0
# 58     GAR-1|SA-13|E6|10    395284   16.280892                  22.0
# 62      GAR-1|A-106|D4|1     84664 -424.739125                  10.0
# 64      GAR-1|A-106|C3|1    296340 -495.790571                  10.0
# 65      GAR-1|A-106|D2|1    190500 -411.000393                  22.0
# 66      GAR-1|A-106|B1|1    192300 -576.809574                  10.0
# 68      GAR-1|A-106|A3|1     89821 -379.179894                  22.0
# 69      GAR-1|A-106|G7|1    467820 -365.744060                  25.0
# 70      GAR-1|A-106|A5|1    279600 -356.612787                  10.0
# 73      GAR-1|A-106|E1|1    513182 -366.267039                  25.0
# 74      GAR-1|A-106|H2|1    301562 -394.371716                  22.0
# 76      GAR-1|A-106|H8|1    441424 -401.984170                  25.0
# 167   MON-1|MTB099|B1|S1    437106 -217.593366                  41.0
# 374   TVC-1|509-069|E5|9    293343 -318.976732                  10.0
# 382  TVC-1|509-069|E11|7    387604 -459.205017                  10.0
# 387   TVC-1|509-069|L5|7    387604 -459.744609                  10.0
#
#      pred_ModDensity  pred_CoolingTime ReactorType pred_ReactorType  \
# 54              0.10       1897.654990         bwr              bwr
# 57              0.10        859.422117         bwr              bwr
# 58              0.50         23.172669         bwr              bwr
# 62              0.10         21.098877         bwr              bwr
# 64              0.70          0.000516         bwr              bwr
# 65              0.30          0.000804         bwr              bwr
# 66              0.50          0.000804         bwr              bwr
# 68              0.30          0.418510         bwr              bwr
# 69              0.71          0.000608         bwr              pwr
# 70              0.70          0.000516         bwr              bwr
# 73              0.71          0.896355         bwr              pwr
# 74              0.90          0.904585         bwr              bwr
# 76              0.71         33.379722         bwr              pwr
# 167             0.71        198.675453         bwr              pwr
# 374             0.50          7.330550         pwr              bwr
# 382             0.10         23.172669         pwr              bwr
# 387             0.10         23.172669         pwr              bwr
#
#      ReactorType_Score  Enrichment  pred_Enrichment  \
# 54                True        2.41             4.83
# 57                True        2.41             4.81
# 58                True        2.41             4.81
# 62                True        2.10             4.83
# 64                True        2.10             4.97
# 65                True        2.10             4.83
# 66                True        1.60             4.83
# 68                True        2.10             4.83
# 69               False        2.10             5.40
# 70                True        2.10             4.29
# 73               False        2.10             4.91
# 74                True        2.10             4.97
# 76               False        2.10             3.86
# 167              False        1.87             1.94
# 374              False        3.13             4.97
# 382              False        3.13             4.81
# 387              False        3.13             4.81
#
#      Relative_Enrichment_Error   Burnup  pred_Burnup  Relative_Burnup_Error  \
# 54                    1.004149   4200.0      6527.94               0.554271
# 57                    0.995851   6640.0     10075.43               0.517384
# 58                    0.995851   8140.0     12296.75               0.510657
# 62                    1.300000   8850.0     15521.57               0.753850
# 64                    1.366667   9140.0     16428.84               0.797466
# 65                    1.300000   9440.0     17276.10               0.830095
# 66                    2.018750   9800.0     19194.08               0.958580
# 68                    1.300000  10510.0     17878.66               0.701109
# 69                    1.571429  10540.0     19326.12               0.833598
# 70                    1.042857  10570.0     17804.03               0.684393
# 73                    1.338095  10800.0     18889.66               0.749043
# 74                    1.366667  11920.0     22560.98               0.892700
# 76                    0.838095  12700.0     20332.54               0.600987
# 167                   0.037433  43800.0     66044.08               0.507856
# 374                   0.587859  19254.0     28751.06               0.493251
# 382                   0.536741  23953.0     36621.40               0.528886
# 387                   0.536741  24313.0     36621.40               0.506248
#
#               OrigenReactor pred_OrigenReactor
# 54         Garigliano-1_BWR            ge7x7-0
# 57         Garigliano-1_BWR           svea64-1
# 58         Garigliano-1_BWR           svea64-1
# 62         Garigliano-1_BWR            ge7x7-0
# 64         Garigliano-1_BWR      atrium10x10-9
# 65         Garigliano-1_BWR           abb8x8-1
# 66         Garigliano-1_BWR           abb8x8-1
# 68         Garigliano-1_BWR            ge7x7-0
# 69         Garigliano-1_BWR             s18x18
# 70         Garigliano-1_BWR      atrium10x10-9
# 73         Garigliano-1_BWR           vver1000
# 74         Garigliano-1_BWR      atrium10x10-9
# 76         Garigliano-1_BWR             w17x17
# 167        Monticello-1_BWR             w17x17
# 374  Trino Vercellese-1_PWR      atrium10x10-9
# 382  Trino Vercellese-1_PWR           svea64-1
# 387  Trino Vercellese-1_PWR           svea64-1

# %%
# finding a good prediction with high max LL
new_df = preds.loc[(preds['Relative_Burnup_Error'] < 0.03) & 
                   (preds['Relative_Enrichment_Error'] < 0.04) & 
                   (preds['ReactorType_Score'] == True) &
                   (preds['MaxLogLL'] > 20), to_print]
new_df
# Out:
#                  sim_idx  pred_idx   MaxLogLL  pred_AvgPowerDensity  \
# 191  NOV-3|RP-3371A|97|3    417261  21.507460                  41.0
# 241       NPD-1|1129|C|1    525314  20.962873                   2.2
# 328  TMI-1|NJ070G|O13|S7    446536  28.662774                  35.0
#
#      pred_ModDensity  pred_CoolingTime ReactorType pred_ReactorType  \
# 191             0.71       1824.411883         pwr              pwr
# 241             0.84       1295.837963        phwr             phwr
# 328             0.71       1521.070654         pwr              pwr
#
#      ReactorType_Score  Enrichment  pred_Enrichment  \
# 191               True       3.300            3.270
# 241               True       0.711            0.711
# 328               True       4.660            4.760
#
#      Relative_Enrichment_Error   Burnup  pred_Burnup  Relative_Burnup_Error  \
# 191                   0.009091   8700.0      8656.02               0.005055
# 241                   0.000000   1622.0      1643.20               0.013070
# 328                   0.021459  22800.0     23170.26               0.016239
#
#                                    OrigenReactor pred_OrigenReactor
# 191                      Novovoronezh-3_VVER-440            ce14x14
# 241  Nuclear Power Demonstration Reactor-1_CANDU            candu37
# 328                      Three Mile Island-1_PWR             w17x17

# %%
new_df.iloc[2:3].to_pickle('sfco_pred_good.pkl')

# %%
# finding a bad prediction
new_df = preds.loc[(preds['Relative_Burnup_Error'] > 0.05) & 
                   (preds['Relative_Enrichment_Error'] > 0.4) & 
                   (preds['ReactorType_Score'] == False), to_print]
                   #(preds['MaxLogLL'] > 20)
new_df
# Out:
#                  sim_idx  pred_idx    MaxLogLL  pred_AvgPowerDensity  \
# 69      GAR-1|A-106|G7|1    467820 -365.744060                  25.0
# 73      GAR-1|A-106|E1|1    513182 -366.267039                  25.0
# 76      GAR-1|A-106|H8|1    441424 -401.984170                  25.0
# 79      GAR-1|A-106|J9|1    505680 -597.108941                  25.0
# 168   MON-1|MTB099|F6|S4    510185 -454.632313                  25.0
# 179   MON-1|MTB099|H8|S4    508985 -348.856503                  41.0
# 287    OBR-1|BE124|G7|P3    283445 -282.275630                  10.0
# 374   TVC-1|509-069|E5|9    293343 -318.976732                  10.0
# 376  TVC-1|509-069|E11|2    390722 -348.469119                  10.0
# 380   TVC-1|509-069|E5|4    387482 -330.973080                  10.0
# 382  TVC-1|509-069|E11|7    387604 -459.205017                  10.0
# 386  TVC-1|509-069|E11|5    387544 -498.586575                  10.0
# 387   TVC-1|509-069|L5|7    387604 -459.744609                  10.0
#
#      pred_ModDensity  pred_CoolingTime ReactorType pred_ReactorType  \
# 69              0.71          0.000608         bwr              pwr
# 73              0.71          0.896355         bwr              pwr
# 76              0.71         33.379722         bwr              pwr
# 79              0.71          0.000578         bwr              pwr
# 168             0.71        129.307730         bwr              pwr
# 179             0.71         30.605773         bwr              pwr
# 287             0.90        102.229393         pwr              bwr
# 374             0.50          7.330550         pwr              bwr
# 376             0.30          1.191198         pwr              bwr
# 380             0.10          1.191198         pwr              bwr
# 382             0.10         23.172669         pwr              bwr
# 386             0.10         23.172669         pwr              bwr
# 387             0.10         23.172669         pwr              bwr
#
#      ReactorType_Score  Enrichment  pred_Enrichment  \
# 69               False        2.10             5.40
# 73               False        2.10             4.91
# 76               False        2.10             3.86
# 79               False        1.60             3.24
# 168              False        2.87             4.36
# 179              False        2.14             3.24
# 287              False        3.00             4.29
# 374              False        3.13             4.97
# 376              False        3.13             4.81
# 380              False        3.13             4.81
# 382              False        3.13             4.81
# 386              False        3.13             4.81
# 387              False        3.13             4.81
#
#      Relative_Enrichment_Error   Burnup  pred_Burnup  Relative_Burnup_Error  \
# 69                    1.571429  10540.0     19326.12               0.833598
# 73                    1.338095  10800.0     18889.66               0.749043
# 76                    0.838095  12700.0     20332.54               0.600987
# 79                    1.025000  14480.0     21061.75               0.454541
# 168                   0.519164  44100.0     63663.56               0.443618
# 179                   0.514019  51100.0     70500.00               0.379648
# 287                   0.430000  31300.0     37088.70               0.184942
# 374                   0.587859  19254.0     28751.06               0.493251
# 376                   0.536741  20628.0     28611.60               0.387027
# 380                   0.536741  23715.0     30940.85               0.304695
# 382                   0.536741  23953.0     36621.40               0.528886
# 386                   0.536741  24250.0     34333.46               0.415813
# 387                   0.536741  24313.0     36621.40               0.506248
#
#               OrigenReactor pred_OrigenReactor
# 69         Garigliano-1_BWR             s18x18
# 73         Garigliano-1_BWR           vver1000
# 76         Garigliano-1_BWR             w17x17
# 79         Garigliano-1_BWR           vver1000
# 168        Monticello-1_BWR           vver1000
# 179        Monticello-1_BWR           vver1000
# 287         Obrigheim-1_PWR      atrium10x10-9
# 374  Trino Vercellese-1_PWR      atrium10x10-9
# 376  Trino Vercellese-1_PWR           svea64-1
# 380  Trino Vercellese-1_PWR           svea64-1
# 382  Trino Vercellese-1_PWR           svea64-1
# 386  Trino Vercellese-1_PWR           svea64-1
# 387  Trino Vercellese-1_PWR           svea64-1

# %%
new_df.iloc[4:5].to_pickle('sfco_pred_bad.pkl')

# %% [markdown]
# ### Enrichment

# %%
preds['Relative_Enrichment_Error'].describe()
# old nuc29 results for reference:
#count    505.000000
#mean       0.165083
#std        0.248423
#min        0.000000
#25%        0.047923
#50%        0.083004
#75%        0.170455
#max        1.750000
# Out:
# count    505.000000
# mean       0.167684
# std        0.234862
# min        0.000000
# 25%        0.053648
# 50%        0.097228
# 75%        0.226923
# max        2.018750
# Name: Relative_Enrichment_Error, dtype: float64

# %%
preds.loc[preds['Relative_Enrichment_Error'] > 1.0, to_print]
# Out:
#               sim_idx  pred_idx  pred_CoolingTime  pred_AvgPowerDensity  \
# 54  GAR-1|SA-13|E6|11     84260       1897.654990                  10.0
# 55  GAR-1|SA-13|E6|13     84364         21.098877                  10.0
# 61   GAR-1|SA-13|E6|5    188647        317.650622                  10.0
# 62   GAR-1|A-106|D4|1     84664         21.098877                  10.0
# 64   GAR-1|A-106|C3|1    296340          0.000516                  10.0
# 65   GAR-1|A-106|D2|1    190500          0.000804                  22.0
# 66   GAR-1|A-106|B1|1    192300          0.000804                  10.0
# 67   GAR-1|A-106|B2|1    271080          0.000516                  22.0
# 68   GAR-1|A-106|A3|1     89821          0.418510                  22.0
# 69   GAR-1|A-106|G7|1    467820          0.000608                  25.0
# 70   GAR-1|A-106|A5|1    279600          0.000516                  10.0
# 73   GAR-1|A-106|E1|1    513182          0.896355                  25.0
# 74   GAR-1|A-106|H2|1    301562          0.904585                  22.0
# 79   GAR-1|A-106|J9|1    505680          0.000578                  25.0
#
#    ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 54         bwr              bwr               True        2.41
# 55         bwr              bwr               True        2.41
# 61         bwr              bwr               True        2.41
# 62         bwr              bwr               True        2.10
# 64         bwr              bwr               True        2.10
# 65         bwr              bwr               True        2.10
# 66         bwr              bwr               True        1.60
# 67         bwr              bwr               True        2.10
# 68         bwr              bwr               True        2.10
# 69         bwr              pwr              False        2.10
# 70         bwr              bwr               True        2.10
# 73         bwr              pwr              False        2.10
# 74         bwr              bwr               True        2.10
# 79         bwr              pwr              False        1.60
#
#     pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 54             4.83                   1.004149   4200.0      6527.94
# 55             4.83                   1.004149   5580.0      8102.96
# 61             4.83                   1.004149   8640.0     12072.11
# 62             4.83                   1.300000   8850.0     15521.57
# 64             4.97                   1.366667   9140.0     16428.84
# 65             4.83                   1.300000   9440.0     17276.10
# 66             4.83                   2.018750   9800.0     19194.08
# 67             4.29                   1.042857  10280.0     15208.79
# 68             4.83                   1.300000  10510.0     17878.66
# 69             5.40                   1.571429  10540.0     19326.12
# 70             4.29                   1.042857  10570.0     17804.03
# 73             4.91                   1.338095  10800.0     18889.66
# 74             4.97                   1.366667  11920.0     22560.98
# 79             3.24                   1.025000  14480.0     21061.75
#
#     Relative_Burnup_Error     OrigenReactor pred_OrigenReactor    MaxLogLL
# 54               0.554271  Garigliano-1_BWR            ge7x7-0   12.026430
# 55               0.452143  Garigliano-1_BWR            ge7x7-0   18.671879
# 61               0.397235  Garigliano-1_BWR           abb8x8-1   -1.958830
# 62               0.753850  Garigliano-1_BWR            ge7x7-0 -424.739125
# 64               0.797466  Garigliano-1_BWR      atrium10x10-9 -495.790571
# 65               0.830095  Garigliano-1_BWR           abb8x8-1 -411.000393
# 66               0.958580  Garigliano-1_BWR           abb8x8-1 -576.809574
# 67               0.479454  Garigliano-1_BWR      atrium10x10-9 -415.165873
# 68               0.701109  Garigliano-1_BWR            ge7x7-0 -379.179894
# 69               0.833598  Garigliano-1_BWR             s18x18 -365.744060
# 70               0.684393  Garigliano-1_BWR      atrium10x10-9 -356.612787
# 73               0.749043  Garigliano-1_BWR           vver1000 -366.267039
# 74               0.892700  Garigliano-1_BWR      atrium10x10-9 -394.371716
# 79               0.454541  Garigliano-1_BWR           vver1000 -597.108941

# %% [markdown]
# # Max Log LL

# %%
print(dfs['unc0']['MaxLogLL'].describe())
print(dfs['unc3']['MaxLogLL'].describe())
# Out:
# count     505.000000
# mean     -220.902308
# std       211.694589
# min     -1759.146357
# 25%      -284.467316
# 50%      -190.569048
# 75%       -82.341520
# max        51.576416
# Name: MaxLogLL, dtype: float64
# count    505.000000
# mean       4.437217
# std       24.045795
# min      -77.449002
# 25%      -10.889628
# 50%       -1.685414
# 75%       13.713790
# max       92.988448
# Name: MaxLogLL, dtype: float64

# %% [markdown]
# # Nuclide Contributions to LL

# %%
nuc29 = ['am241', 'am242m', 'am243', 
         'cm242', 'cm244', 
         'cs134', 'cs137', 
         'eu154', 
         'nd143', 'nd144', 'nd145', 'nd146', 'nd148', 'nd150',
         'np237', 
         'pu238', 'pu239', 'pu240', 'pu241', 'pu242',
         'sm147', 'sm149', 'sm150', 'sm151', 'sm152',
         'u234', 'u235', 'u236', 'u238']

# %%
logpdf_df.sample(10)
# Out:
#                             am241  am242m      am243      cm242      cm244  \
# MON-1|MTB099|A1|S1            NaN     NaN        NaN   6.163488        NaN
# YNK-1|E5|C-A6|G-103           NaN     NaN        NaN        NaN        NaN
# GAR-1|A-106|B1|1      -184.231793     NaN -23.727609   7.502274   6.382196
# FOR-3|14595|F6|FFBU     -4.356343     NaN   2.795038        NaN -10.238029
# JPD-1|A-18|C3|-293       1.604227     NaN        NaN  14.106719  16.095196
# OBR-1|BE210|K14|P1       5.553794     NaN        NaN   6.390365   5.166247
# NOV-4|13602496|25|19          NaN     NaN  -3.199363        NaN   4.261703
# GAR-1|A-106|G7|1         5.164808     NaN        NaN   2.237062   9.101566
# KOL-3|144-46879|61|13  -51.436577     NaN -11.368869   3.140377 -73.032956
# FDN-2|2F2D8|H4|MS1     -61.780111     NaN -42.937074   2.165411 -10.677867
#
#                             cs134      cs137     eu154     nd143     nd144  \
# MON-1|MTB099|A1|S1            NaN        NaN       NaN       NaN       NaN
# YNK-1|E5|C-A6|G-103           NaN        NaN       NaN       NaN       NaN
# GAR-1|A-106|B1|1              NaN        NaN       NaN       NaN       NaN
# FOR-3|14595|F6|FFBU           NaN        NaN       NaN  2.065190 -2.865455
# JPD-1|A-18|C3|-293            NaN   4.310332       NaN  3.857968  4.036530
# OBR-1|BE210|K14|P1            NaN -36.479233       NaN       NaN       NaN
# NOV-4|13602496|25|19          NaN        NaN       NaN       NaN       NaN
# GAR-1|A-106|G7|1              NaN        NaN       NaN       NaN       NaN
# KOL-3|144-46879|61|13 -139.629737   0.711926 -8.602772 -0.425874       NaN
# FDN-2|2F2D8|H4|MS1            NaN        NaN       NaN  1.967466  0.904727
#
#                        ...     pu242      sm147      sm149      sm150  \
# MON-1|MTB099|A1|S1     ... -4.689277        NaN        NaN        NaN
# YNK-1|E5|C-A6|G-103    ...  5.189880        NaN        NaN        NaN
# GAR-1|A-106|B1|1       ... -1.202706        NaN        NaN        NaN
# FOR-3|14595|F6|FFBU    ...  0.005492        NaN        NaN        NaN
# JPD-1|A-18|C3|-293     ...  9.219027        NaN        NaN        NaN
# OBR-1|BE210|K14|P1     ... -3.185852        NaN        NaN        NaN
# NOV-4|13602496|25|19   ... -0.146758        NaN        NaN        NaN
# GAR-1|A-106|G7|1       ... -8.965300        NaN        NaN        NaN
# KOL-3|144-46879|61|13  ... -8.727153 -91.516096 -92.573277 -43.205261
# FDN-2|2F2D8|H4|MS1     ... -0.804464        NaN        NaN        NaN
#
#                           sm151      sm152       u234       u235       u236  \
# MON-1|MTB099|A1|S1          NaN        NaN -58.643448  -4.534996  -2.540176
# YNK-1|E5|C-A6|G-103         NaN        NaN -28.752399  -2.356046   0.167525
# GAR-1|A-106|B1|1            NaN        NaN        NaN        NaN        NaN
# FOR-3|14595|F6|FFBU         NaN        NaN -12.599263   0.526847 -19.191779
# JPD-1|A-18|C3|-293          NaN        NaN -68.018665  -5.928735   1.350999
# OBR-1|BE210|K14|P1          NaN        NaN        NaN  -8.001450  -0.499738
# NOV-4|13602496|25|19        NaN        NaN   0.669257  -7.207012   0.220390
# GAR-1|A-106|G7|1            NaN        NaN        NaN        NaN        NaN
# KOL-3|144-46879|61|13  5.845147 -55.353917   3.263634 -10.379145   0.196043
# FDN-2|2F2D8|H4|MS1          NaN        NaN  -7.188503  -4.700013  -7.015950
#
#                            u238
# MON-1|MTB099|A1|S1    -4.910649
# YNK-1|E5|C-A6|G-103   -4.789144
# GAR-1|A-106|B1|1            NaN
# FOR-3|14595|F6|FFBU   -4.782710
# JPD-1|A-18|C3|-293    -4.802140
# OBR-1|BE210|K14|P1    -4.781431
# NOV-4|13602496|25|19  -4.763148
# GAR-1|A-106|G7|1            NaN
# KOL-3|144-46879|61|13 -4.765546
# FDN-2|2F2D8|H4|MS1    -5.562809
#
# [10 rows x 29 columns]

# %%
for nuc in nuc29:
    desc = logpdf_df[nuc].describe()
    print(desc[['count', 'mean', 'std', 'min', 'max']])
# Out:
# count    237.000000
# mean     -31.333772
# std       53.489034
# min     -194.695673
# max        7.258579
# Name: am241, dtype: float64
# count    110.000000
# mean     -23.854524
# std       50.385684
# min     -248.774750
# max       10.275533
# Name: am242m, dtype: float64
# count    203.000000
# mean      -7.828539
# std       16.973707
# min      -98.152084
# max        9.532066
# Name: am243, dtype: float64
# count    214.000000
# mean      -1.295015
# std       19.955262
# min     -140.361241
# max       19.656788
# Name: cm242, dtype: float64
# count    269.000000
# mean     -15.300685
# std       37.722623
# min     -180.310354
# max       16.717730
# Name: cm244, dtype: float64
# count    113.000000
# mean     -27.694817
# std       53.129003
# min     -188.228578
# max        9.011785
# Name: cs134, dtype: float64
# count    185.000000
# mean      -3.531138
# std       12.885717
# min      -78.277985
# max        4.310332
# Name: cs137, dtype: float64
# count    100.000000
# mean     -19.015840
# std       41.451448
# min     -163.587753
# max        8.841122
# Name: eu154, dtype: float64
# count    162.000000
# mean       0.758105
# std        2.855175
# min      -22.259767
# max        4.221300
# Name: nd143, dtype: float64
# count    113.000000
# mean      -1.980011
# std        7.418851
# min      -46.160962
# max        4.206050
# Name: nd144, dtype: float64
# count    162.000000
# mean       1.422476
# std        1.845679
# min       -8.479576
# max        4.586888
# Name: nd145, dtype: float64
# count    139.000000
# mean       0.600020
# std        4.423793
# min      -38.967355
# max        4.816707
# Name: nd146, dtype: float64
# count    275.000000
# mean       1.797551
# std        2.890282
# min      -20.204363
# max        6.021463
# Name: nd148, dtype: float64
# count    121.000000
# mean       2.372619
# std        2.879679
# min      -15.009582
# max        6.212637
# Name: nd150, dtype: float64
# count    155.000000
# mean     -11.337064
# std       29.191238
# min     -172.681208
# max        4.711986
# Name: np237, dtype: float64
# count    369.000000
# mean     -15.278464
# std       43.580450
# min     -194.860840
# max        8.571475
# Name: pu238, dtype: float64
# count    505.000000
# mean      -5.201209
# std        7.449006
# min      -36.775505
# max        1.896080
# Name: pu239, dtype: float64
# count    505.000000
# mean     -99.752460
# std      100.655206
# min     -587.607443
# max        4.558224
# Name: pu240, dtype: float64
# count    504.000000
# mean     -11.071503
# std       34.367988
# min     -177.974650
# max        8.202528
# Name: pu241, dtype: float64
# count    505.000000
# mean     -11.227257
# std       18.405061
# min     -150.944494
# max        9.724004
# Name: pu242, dtype: float64
# count     97.000000
# mean     -20.079498
# std       44.737238
# min     -227.174990
# max        3.836046
# Name: sm147, dtype: float64
# count     97.000000
# mean     -11.570358
# std       36.627273
# min     -228.459797
# max        8.496927
# Name: sm149, dtype: float64
# count    97.000000
# mean     -2.233123
# std      12.072564
# min     -80.821552
# max       3.624387
# Name: sm150, dtype: float64
# count     97.000000
# mean      -4.609438
# std       49.041039
# min     -463.298668
# max        6.724889
# Name: sm151, dtype: float64
# count    97.000000
# mean     -1.543973
# std      14.273574
# min     -72.059023
# max       4.561289
# Name: sm152, dtype: float64
# count    355.000000
# mean     -26.458257
# std       33.366552
# min     -412.555328
# max        4.071894
# Name: u234, dtype: float64
# count    479.000000
# mean      -5.385528
# std        7.351156
# min      -38.100251
# max        4.067867
# Name: u235, dtype: float64
# count    462.000000
# mean      -2.714880
# std        6.724798
# min      -71.320212
# max        3.418583
# Name: u236, dtype: float64
# count    433.000000
# mean      -4.796226
# std        0.095472
# min       -6.036903
# max       -4.737944
# Name: u238, dtype: float64

# %% [markdown]
# # Look at ratio values for a single prediction

# %%
sim_id = 'VAN-2|EF05|WZR0058|E58-88'
pred_id = 445584
preds.loc[preds['sim_idx']==sim_id, to_print]
# Out:
#                        sim_idx  pred_idx  pred_CoolingTime  \
# 418  VAN-2|EF05|WZR0058|E58-88    445584       2066.125663
#
#      pred_AvgPowerDensity ReactorType pred_ReactorType  ReactorType_Score  \
# 418                  25.0         pwr              pwr               True
#
#      Enrichment  pred_Enrichment  Relative_Enrichment_Error   Burnup  \
# 418         4.5             4.76                   0.057778  43520.0
#
#      pred_Burnup  Relative_Burnup_Error    OrigenReactor pred_OrigenReactor  \
# 418      38041.0               0.125896  Vandellos-2_PWR             w17x17
#
#       MaxLogLL
# 418 -208.47935

# %%
y_mes = sfco.loc[sfco.index == sim_id].squeeze().drop(lbls)
y_sim = XY.loc[XY.index == pred_id].squeeze().drop(lbls+nonlbls)
y_logpdf = logpdf_df.loc[logpdf_df.index == sim_id].squeeze()
df = pd.DataFrame([y_mes, y_sim])
df.loc['Abs Diff'] = np.abs(df.loc[pred_id] - df.loc[sim_id])
df.loc['% Diff'] = df.loc['Abs Diff'] * 100 / df.loc[sim_id]
df.loc['LogPDF'] = y_logpdf

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#                                am241    am242m      am243     cm242  \
# VAN-2|EF05|WZR0058|E58-88   0.252000  0.000000   0.090100  0.000000
# 445584                      0.480000  0.001284   0.099110  0.000006
# Abs Diff                    0.228000  0.001284   0.009010  0.000006
# % Diff                     90.476190       inf  10.000000       inf
# LogPDF                    -42.314237       NaN   2.735426       NaN
#
#                                cm244     cs134      cs137     eu154     nd143  \
# VAN-2|EF05|WZR0058|E58-88   0.016500  0.018400   1.430000  0.016600  1.020000
# 445584                      0.024920  0.018590   1.215000  0.017220  1.014000
# Abs Diff                    0.008420  0.000190   0.215000  0.000620  0.006000
# % Diff                     51.030303  1.032609  15.034965  3.734940  0.588235
# LogPDF                    -17.063865  6.041033  -4.380546  5.879211  2.055888
#
#                               nd144     nd145     nd146      nd148      nd150  \
# VAN-2|EF05|WZR0058|E58-88  1.650000  0.842000  0.852000   0.484000   0.235000
# 445584                     1.498000  0.805900  0.799000   0.425600   0.198300
# Abs Diff                   0.152000  0.036100  0.053000   0.058400   0.036700
# % Diff                     9.212121  4.287411  6.220657  12.066116  15.617021
# LogPDF                    -0.386514  1.891277  1.421177  -0.834709  -3.155644
#
#                               np237      pu238      pu239      pu240  \
# VAN-2|EF05|WZR0058|E58-88  0.610000   0.268000   6.140000    2.40000
# 445584                     0.622000   0.227300   5.378000    1.24200
# Abs Diff                   0.012000   0.040700   0.762000    1.15800
# % Diff                     1.967213  15.186567  12.410423   48.25000
# LogPDF                     2.477168  -2.854112  -3.620641 -172.00163
#
#                                pu241     pu242     sm147      sm149     sm150  \
# VAN-2|EF05|WZR0058|E58-88   1.130000  0.556000  0.275000   0.003390  0.331000
# 445584                      1.305000  0.559400  0.270400   0.003924  0.331000
# Abs Diff                    0.175000  0.003400  0.004600   0.000534  0.000000
# % Diff                     15.486726  0.611511  1.672727  15.752212  0.000000
# LogPDF                     -1.785951  2.650296  3.326766   3.913578  3.182431
#
#                               sm151     sm152      u234       u235      u236  \
# VAN-2|EF05|WZR0058|E58-88  0.014400  0.125000  0.237000  12.900000  5.510000
# 445584                     0.014780  0.113800  0.228700  15.890000  5.548000
# Abs Diff                   0.000380  0.011200  0.008300   2.990000  0.038000
# % Diff                     2.638889  8.960000  3.502110  23.178295  0.689655
# LogPDF                     6.159069  2.312875  3.288715  -7.770385  0.353974
#
#                             u238
# VAN-2|EF05|WZR0058|E58-88    0.0
# 445584                     928.7
# Abs Diff                   928.7
# % Diff                       inf
# LogPDF                       NaN
