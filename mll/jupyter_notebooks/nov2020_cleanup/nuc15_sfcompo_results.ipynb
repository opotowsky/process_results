# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Data Setup & Functions

# %%
from mll_calc.mll_pred import format_XY, convert_g_to_mgUi

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

# %%
def loop_sfco(XY, test, pred, unc, lbls, nonlbls):
    xy_cols = XY.columns.tolist()
    for col in nonlbls: xy_cols.remove(col)
    test = test[xy_cols]
    
    logpdf_df = pd.DataFrame()
    for test_idx, row in test.iterrows():
        test_sample = row.drop(lbls)
        test_answer = row[lbls]
        pred_row = pred.loc[pred['sim_idx'] == test_idx]
        pred_idx = pred_row['pred_idx'].values[0]
        train_row = XY.loc[pred_idx].drop(lbls+nonlbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = pred_row['MaxLogLL'].values[0]
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=test_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %% [markdown]
# ### Train and Test DBs

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

train_pkl = '~/sims_n_results/simupdates_aug2020/not-scaled_nuc15.pkl'
XY = format_XY(train_pkl)
XY = convert_g_to_mgUi(XY, lbls+nonlbls)

sfco_pkl = '~/sfcompo/format_clean/sfcompo_nuc15.pkl'
sfco = pd.read_pickle(sfco_pkl)

# %% [markdown]
# ### LL Calc Results

# %%
sfcompo_results = '~/sims_n_results/simupdates_aug2020/sfco15/'

uncs = [0.05, 0.1, 0.15, 0.2]
job_dirs = ['Job' + str(i) + '_unc' + str(unc) for i, unc in enumerate(uncs)]
dfs = {}
for i, unc_job in enumerate(job_dirs):
    dfs['unc' + str(i)] = pd.read_csv(sfcompo_results + unc_job + '/' + unc_job + '.csv')

for dfname in list(dfs.keys()):
    df = dfs[dfname]
    df['Relative_Burnup_Error'] = df['Burnup_Error'] / df['Burnup']
    df['Relative_Enrichment_Error'] = df['Enrichment_Error'] / df['Enrichment']

# For ease of only viewing 5% case for now
preds = dfs['unc0']

# %% [markdown]
# ### LogPDF (wrt nuclide) results

# %%
unc = 0.05
logpdf_df = loop_sfco(XY, sfco, preds, unc, lbls, nonlbls)

# %% [markdown]
# # Explore Errors

# %% [markdown]
# ### Burnup

# %%
preds['Relative_Burnup_Error'].describe()
#old results for reference:
#count    544.000000
#mean       0.332184
#std        0.285241
#min        0.000074
#25%        0.193478
#50%        0.297102
#75%        0.393373
#max        2.743641
# Out:
# count    505.000000
# mean       0.187539
# std        0.155398
# min        0.000408
# 25%        0.058485
# 50%        0.153846
# 75%        0.298556
# max        1.503097
# Name: Relative_Burnup_Error, dtype: float64

# %%
to_print = ['sim_idx', 'pred_idx', 'pred_CoolingTime', 'AvgPowerDensity', 
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Relative_Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Relative_Burnup_Error',
            'OrigenReactor', 'pred_OrigenReactor', 'MaxLogLL']
preds.loc[preds['Relative_Burnup_Error'] > 0.49, to_print]
# Out:
#                    sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 24      FDN-1|2F1ZN2|C3|UB    312854       1083.936839             41.0
# 38    FDN-2|2F2D3|H5|TU302    244758       1407.176700             41.0
# 39    FDN-2|2F2D3|A4|TU306    287604       2011.587621             25.0
# 49    FDN-2|2F2D8|H5|TU503    187444         21.396677             10.0
# 54       GAR-1|SA-13|E6|11    114548        464.008668             25.0
# 55       GAR-1|SA-13|E6|13    171792        812.044584             10.0
# 64        GAR-1|A-106|C3|1    166978       7097.519283             10.0
# 202         NOV-4|213|25|9    290040          0.000776             41.0
# 236         NPD-1|1022|A|1     30358       6973.335475             10.0
# 284  OBR-1|BE210|G14|P5(1)    241572        854.157139             25.0
# 287      OBR-1|BE124|G7|P3    264268       2473.486279             41.0
# 368     TVC-1|509-049|J8|7    351993       3308.216103             25.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 24          bwr              pwr              False       4.900
# 38          bwr              pwr              False       3.400
# 39          bwr              pwr              False       3.400
# 49          bwr              bwr               True       3.400
# 54          bwr              bwr               True       2.410
# 55          bwr              bwr               True       2.410
# 64          bwr              bwr               True       2.100
# 202         pwr              pwr               True       3.600
# 236        phwr              bwr              False       0.711
# 284         pwr              bwr              False       2.830
# 287         pwr              pwr               True       3.000
# 368         pwr              pwr               True       2.719
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 24              0.51                   0.895918  47490.0     18330.69
# 38              0.51                   0.850000  31400.0     15867.31
# 39              0.50                   0.852941  32300.0     16206.28
# 49              0.50                   0.852941  55600.0     27569.97
# 54              5.23                   1.170124   4200.0      7656.06
# 55              5.11                   1.120332   5580.0      9700.27
# 64              4.23                   1.014286   9140.0     14697.28
# 202             0.50                   0.861111  27600.0     11834.22
# 236             2.74                   2.853727    791.0      1979.95
# 284             5.05                   0.784452  30100.0     45382.93
# 287             5.39                   0.796667  31300.0     49455.77
# 368             5.15                   0.894079  15343.0     22879.33
#
#      Relative_Burnup_Error                                OrigenReactor  \
# 24                0.614009                        Fukushima-Daini-1_BWR
# 38                0.494672                        Fukushima-Daini-2_BWR
# 39                0.498258                        Fukushima-Daini-2_BWR
# 49                0.504137                        Fukushima-Daini-2_BWR
# 54                0.822871                             Garigliano-1_BWR
# 55                0.738400                             Garigliano-1_BWR
# 64                0.608018                             Garigliano-1_BWR
# 202               0.571224                      Novovoronezh-4_VVER-440
# 236               1.503097  Nuclear Power Demonstration Reactor-1_CANDU
# 284               0.507739                              Obrigheim-1_PWR
# 287               0.580057                              Obrigheim-1_PWR
# 368               0.491190                       Trino Vercellese-1_PWR
#
#     pred_OrigenReactor    MaxLogLL
# 24             bw15x15   -9.539628
# 38             ce14x14    0.743836
# 39              s18x18   -0.007534
# 49            svea64-1    5.905322
# 54            abb8x8-1   16.508729
# 55       atrium10x10-9   14.079438
# 64       atrium10x10-9 -112.530928
# 202             s18x18  -28.451755
# 236            ge7x7-0  -24.645155
# 284           svea64-1  -20.559729
# 287            ce14x14  -31.212889
# 368           vver1000    1.042516

# %% [markdown]
# ### Enrichment

# %%
preds['Relative_Enrichment_Error'].describe()
# Out:
# count    505.000000
# mean       0.369961
# std        0.289978
# min        0.000000
# 25%        0.119444
# 50%        0.288235
# 75%        0.611765
# max        2.853727
# Name: Relative_Enrichment_Error, dtype: float64

# %%
preds.loc[preds['Relative_Enrichment_Error'] > 0.8, to_print]
# Out:
#                    sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 16   COO-1|CZ346|ADD2974|J    307073       6067.268722             25.0
# 17   COO-1|CZ346|ADD2974|U    288870       3124.794142             35.0
# 18   COO-1|CZ346|ADD2966|K    310354       3241.942859             25.0
# 19   COO-1|CZ346|ADD2966|T    310354       3241.942859             25.0
# 24      FDN-1|2F1ZN2|C3|UB    312854       1083.936839             41.0
# 29      FDN-1|2F1ZN3|C3|UB      1205         84.338574             10.0
# 38    FDN-2|2F2D3|H5|TU302    244758       1407.176700             41.0
# 39    FDN-2|2F2D3|A4|TU306    287604       2011.587621             25.0
# 49    FDN-2|2F2D8|H5|TU503    187444         21.396677             10.0
# 50    FDN-2|2F2D8|A4|TU506      1149        473.850856             10.0
# 52    FDN-2|2F2D8|H5|TU502    288008        378.041108             25.0
# 54       GAR-1|SA-13|E6|11    114548        464.008668             25.0
# 55       GAR-1|SA-13|E6|13    171792        812.044584             10.0
# 64        GAR-1|A-106|C3|1    166978       7097.519283             10.0
# 85      GRM-1|C16|C5|K2680     51254       1145.475712             10.0
# 165     MON-1|MTB099|F6|S5    307105       2534.023064             25.0
# 168     MON-1|MTB099|F6|S4    307285       2534.023064             25.0
# 169     MON-1|MTB099|F6|S1    310512        854.721340             25.0
# 202         NOV-4|213|25|9    290040          0.000776             41.0
# 236         NPD-1|1022|A|1     30358       6973.335475             10.0
# 268  OBR-1|BE210|G14|P5(2)    120368        464.008668             25.0
# 270     OBR-1|BE210|K14|P1    180909        487.030539             25.0
# 293  OBR-1|BE210|K14|P3(1)    264384       2167.091819             41.0
# 305     QC-1|LYD396|G5|D4A    310862          0.815984             25.0
# 368     TVC-1|509-049|J8|7    351993       3308.216103             25.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 16          bwr              pwr              False       2.940
# 17          bwr              pwr              False       2.940
# 18          bwr              pwr              False       2.940
# 19          bwr              pwr              False       2.940
# 24          bwr              pwr              False       4.900
# 29          bwr              bwr               True       4.900
# 38          bwr              pwr              False       3.400
# 39          bwr              pwr              False       3.400
# 49          bwr              bwr               True       3.400
# 50          bwr              bwr               True       3.400
# 52          bwr              pwr              False       3.400
# 54          bwr              bwr               True       2.410
# 55          bwr              bwr               True       2.410
# 64          bwr              bwr               True       2.100
# 85          bwr              bwr               True       2.530
# 165         bwr              pwr              False       2.870
# 168         bwr              pwr              False       2.870
# 169         bwr              pwr              False       2.870
# 202         pwr              pwr               True       3.600
# 236        phwr              bwr              False       0.711
# 268         pwr              bwr              False       2.830
# 270         pwr              bwr              False       2.830
# 293         pwr              pwr               True       2.830
# 305         bwr              pwr              False       3.000
# 368         pwr              pwr               True       2.719
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 16              5.48                   0.863946  29230.0     41063.62
# 17              0.50                   0.829932  31040.0     16206.28
# 18              0.51                   0.826531  33070.0     18330.69
# 19              0.51                   0.826531  33940.0     18330.69
# 24              0.51                   0.895918  47490.0     18330.69
# 29              0.50                   0.897959  68250.0     36458.87
# 38              0.51                   0.850000  31400.0     15867.31
# 39              0.50                   0.852941  32300.0     16206.28
# 49              0.50                   0.852941  55600.0     27569.97
# 50              0.50                   0.852941  57500.0     34140.74
# 52              0.50                   0.852941  58900.0     33814.22
# 54              5.23                   1.170124   4200.0      7656.06
# 55              5.11                   1.120332   5580.0      9700.27
# 64              4.23                   1.014286   9140.0     14697.28
# 85              4.57                   0.806324  18200.0     21745.58
# 165             5.48                   0.909408  32700.0     45319.61
# 168             5.48                   0.909408  44100.0     65306.25
# 169             0.51                   0.822300  44400.0     28470.89
# 202             0.50                   0.861111  27600.0     11834.22
# 236             2.74                   2.853727    791.0      1979.95
# 268             5.23                   0.848057  24200.0     34658.13
# 270             5.11                   0.805654  25500.0     33252.52
# 293             5.39                   0.904594  36600.0     53676.47
# 305             0.51                   0.830000  62000.0     50538.28
# 368             5.15                   0.894079  15343.0     22879.33
#
#      Relative_Burnup_Error                                OrigenReactor  \
# 16                0.404845                                 Cooper-1_BWR
# 17                0.477890                                 Cooper-1_BWR
# 18                0.445700                                 Cooper-1_BWR
# 19                0.459909                                 Cooper-1_BWR
# 24                0.614009                        Fukushima-Daini-1_BWR
# 29                0.465804                        Fukushima-Daini-1_BWR
# 38                0.494672                        Fukushima-Daini-2_BWR
# 39                0.498258                        Fukushima-Daini-2_BWR
# 49                0.504137                        Fukushima-Daini-2_BWR
# 50                0.406248                        Fukushima-Daini-2_BWR
# 52                0.425905                        Fukushima-Daini-2_BWR
# 54                0.822871                             Garigliano-1_BWR
# 55                0.738400                             Garigliano-1_BWR
# 64                0.608018                             Garigliano-1_BWR
# 85                0.194812                          Gundremmingen-1_BWR
# 165               0.385921                             Monticello-1_BWR
# 168               0.480867                             Monticello-1_BWR
# 169               0.358764                             Monticello-1_BWR
# 202               0.571224                      Novovoronezh-4_VVER-440
# 236               1.503097  Nuclear Power Demonstration Reactor-1_CANDU
# 268               0.432154                              Obrigheim-1_PWR
# 270               0.304020                              Obrigheim-1_PWR
# 293               0.466570                              Obrigheim-1_PWR
# 305               0.184866                            Quad Cities-1_BWR
# 368               0.491190                       Trino Vercellese-1_PWR
#
#     pred_OrigenReactor    MaxLogLL
# 16              s18x18  -42.394934
# 17              s18x18  -21.978731
# 18             bw15x15  -23.522626
# 19             bw15x15  -16.210298
# 24             bw15x15   -9.539628
# 29             ge7x7-0    1.116023
# 38             ce14x14    0.743836
# 39              s18x18   -0.007534
# 49            svea64-1    5.905322
# 50             ge7x7-0    1.177680
# 52              s18x18   -3.204798
# 54            abb8x8-1   16.508729
# 55       atrium10x10-9   14.079438
# 64       atrium10x10-9 -112.530928
# 85             ge7x7-0   -4.528192
# 165             s18x18  -26.453840
# 168             s18x18  -38.530780
# 169            bw15x15   -3.103058
# 202             s18x18  -28.451755
# 236            ge7x7-0  -24.645155
# 268           abb8x8-1  -12.942137
# 270      atrium10x10-9  -12.845860
# 293            ce14x14  -23.670666
# 305            bw15x15   -1.520093
# 368           vver1000    1.042516

# %% [markdown]
# # Max Log LL

# %%
print(dfs['unc0']['MaxLogLL'].describe())
print(dfs['unc3']['MaxLogLL'].describe())
# Out:
# count    505.000000
# mean     -12.379540
# std       46.738361
# min     -438.446156
# 25%      -12.343408
# 50%       -4.528192
# 75%        6.085927
# max       52.071185
# Name: MaxLogLL, dtype: float64
# count    505.000000
# mean       6.654287
# std        9.238379
# min       -5.505686
# 25%       -0.227195
# 50%        2.738450
# 75%       11.888770
# max       43.619047
# Name: MaxLogLL, dtype: float64

# %% [markdown]
# # Nuclide Contributions to LL

# %%
nuc15 = ['cs133', 'cs134', 'cs135', 'cs137', 
         'eu153', 'eu154', 'ba136', 'ba138', 
         'sm149', 'sm150', 'sm152', 
         'pu239', 'pu240', 'pu241', 'pu242']

# %%
logpdf_df.sample(10)
# Out:
#                            ba136  ba138     cs133     cs134     cs135  \
# OBR-1|BE171|1|88             NaN    NaN       NaN       NaN       NaN
# TMI-1|NJ070G|O1|S2           NaN    NaN       NaN  5.428716       NaN
# GAR-1|A-106|A9|1             NaN    NaN       NaN       NaN       NaN
# YNK-1|E6|SE-F5|N-25          NaN    NaN       NaN       NaN       NaN
# NOV-4|213|64|15              NaN    NaN       NaN       NaN       NaN
# FDN-2|2F2DN23|SF98|4         NaN    NaN       NaN  3.746061       NaN
# KOL-3|144-46879|62|81        NaN    NaN  1.272586  7.406385 -8.675377
# JPD-1|A-20|C3|KA-1040+171    NaN    NaN       NaN  8.562583       NaN
# TVC-1|509-069|E11|2K         NaN    NaN       NaN       NaN       NaN
# CCL-1|D101|MLA098|P          NaN    NaN       NaN       NaN       NaN
#
#                               cs137     eu153     eu154      pu239      pu240  \
# OBR-1|BE171|1|88                NaN       NaN       NaN   0.377889  -8.129700
# TMI-1|NJ070G|O1|S2         1.374932  1.377732       NaN   0.355431 -13.667326
# GAR-1|A-106|A9|1                NaN       NaN       NaN -16.657813  -0.055950
# YNK-1|E6|SE-F5|N-25             NaN       NaN       NaN  -1.117904  -5.749993
# NOV-4|213|64|15                 NaN       NaN       NaN  -0.643557 -10.819088
# FDN-2|2F2DN23|SF98|4      -0.953860       NaN  5.476027   0.707135 -11.546844
# KOL-3|144-46879|62|81      0.711368 -3.352758  0.760259  -2.735557  -7.711641
# JPD-1|A-20|C3|KA-1040+171  1.944895       NaN  9.378490  -2.473292   2.549989
# TVC-1|509-069|E11|2K            NaN       NaN       NaN   0.139271  -8.514064
# CCL-1|D101|MLA098|P             NaN       NaN       NaN  -0.915969  -7.962498
#
#                                pu241      pu242     sm149     sm150      sm152
# OBR-1|BE171|1|88            2.012587   1.126241       NaN       NaN        NaN
# TMI-1|NJ070G|O1|S2         -0.290394   1.644359  7.507232  0.893431   3.258200
# GAR-1|A-106|A9|1          -61.466251   2.451982       NaN       NaN        NaN
# YNK-1|E6|SE-F5|N-25         1.492756  -1.463265       NaN       NaN        NaN
# NOV-4|213|64|15             1.671907  -0.001896       NaN       NaN        NaN
# FDN-2|2F2DN23|SF98|4        0.726137 -13.063159  5.055513 -0.666196  -4.559284
# KOL-3|144-46879|62|81      -6.262424  -0.792971 -3.838983  1.490876 -16.542275
# JPD-1|A-20|C3|KA-1040+171   4.435464   6.457960       NaN       NaN        NaN
# TVC-1|509-069|E11|2K        2.194199   1.904718       NaN       NaN        NaN
# CCL-1|D101|MLA098|P         2.110648  -0.685518       NaN       NaN        NaN

# %%
for nuc in nuc15:
    desc = logpdf_df[nuc].describe()
    print(desc[['count', 'mean', 'std', 'min', 'max']])
# Out:
# count     46.000000
# mean      -5.609692
# std       27.251557
# min     -151.341834
# max        2.242629
# Name: cs133, dtype: float64
# count    113.000000
# mean       6.143763
# std        2.554392
# min       -5.554422
# max       10.838051
# Name: cs134, dtype: float64
# count    40.000000
# mean     -0.109266
# std       3.591226
# min     -14.249798
# max       2.915950
# Name: cs135, dtype: float64
# count    185.000000
# mean       0.500056
# std        3.120128
# min      -16.736625
# max        4.618208
# Name: cs137, dtype: float64
# count     83.000000
# mean     -12.082937
# std       40.759924
# min     -158.826684
# max        4.718569
# Name: eu153, dtype: float64
# count    100.000000
# mean      -7.950006
# std       38.689436
# min     -158.745997
# max       11.282856
# Name: eu154, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# max      NaN
# Name: ba136, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# max      NaN
# Name: ba138, dtype: float64
# count    97.000000
# mean      2.897750
# std      13.626013
# min     -86.865380
# max       8.575565
# Name: sm149, dtype: float64
# count    97.000000
# mean      1.155676
# std       7.373739
# min     -66.916230
# max       3.719975
# Name: sm150, dtype: float64
# count    97.000000
# mean      1.134414
# std       9.780833
# min     -81.867145
# max       4.572146
# Name: sm152, dtype: float64
# count    505.000000
# mean      -1.797121
# std        5.942781
# min      -61.986710
# max        2.038518
# Name: pu239, dtype: float64
# count    505.000000
# mean      -7.429194
# std        7.806711
# min      -52.215194
# max        4.882197
# Name: pu240, dtype: float64
# count    504.000000
# mean      -1.353419
# std       16.956210
# min     -114.454272
# max        7.940745
# Name: pu241, dtype: float64
# count    505.000000
# mean      -0.277091
# std        7.494278
# min      -93.266660
# max       11.263003
# Name: pu242, dtype: float64

# %% [markdown]
# # Look at ratio values for a single prediction

# %%
sim_id = 'VAN-2|EF05|WZR0058|E58-88'
pred_id = 43225
preds.loc[preds['sim_idx']==sim_id, to_print]
# Out:
#                        sim_idx  pred_idx  pred_CoolingTime  AvgPowerDensity  \
# 418  VAN-2|EF05|WZR0058|E58-88    352405       2359.896319             25.0
#
#     ReactorType pred_ReactorType  ReactorType_Score  Enrichment  \
# 418         pwr              pwr               True         4.5
#
#      pred_Enrichment  Relative_Enrichment_Error   Burnup  pred_Burnup  \
# 418             5.15                   0.144444  43520.0     42872.97
#
#      Relative_Burnup_Error    OrigenReactor pred_OrigenReactor  MaxLogLL
# 418               0.014867  Vandellos-2_PWR           vver1000  7.961585

# %%
y_mes = sfco.loc[sfco.index == sim_id].squeeze().drop(lbls)
y_sim = XY.loc[XY.index == pred_id].squeeze().drop(lbls+nonlbls)
y_logpdf = logpdf_df.loc[logpdf_df.index == sim_id].squeeze()
df = pd.DataFrame([y_mes, y_sim])
df.loc['Abs Diff'] = np.abs(df.loc[pred_id] - df.loc[sim_id])
df.loc['% Diff'] = df.loc['Abs Diff'] * 100 / df.loc[sim_id]
df.loc['LogPDF'] = y_logpdf

# %%
df
# Out:
#                               cs133      cs134      cs135      cs137  \
# VAN-2|EF05|WZR0058|E58-88  1.400000   0.018400   0.784000   1.430000
# 43225                      1.279000   0.015460   0.622700   1.154000
# Abs Diff                   0.121000   0.002940   0.161300   0.276000
# % Diff                     8.642857  15.978261  20.573980  19.300699
# LogPDF                     1.184735   3.405350   2.050726   0.797028
#
#                                eu153      eu154    ba136  ba138      sm149  \
# VAN-2|EF05|WZR0058|E58-88   0.133000   0.016600  0.00000  0.000   0.003390
# 43225                       0.118900   0.014720  0.02285  1.458   0.002967
# Abs Diff                    0.014100   0.001880  0.02285  1.458   0.000423
# % Diff                     10.601504  11.325301      inf    inf  12.477876
# LogPDF                      2.847683   2.059226      NaN    NaN   3.464595
#
#                               sm150     sm152      pu239      pu240  \
# VAN-2|EF05|WZR0058|E58-88  0.331000  0.125000   6.140000   2.400000
# 43225                      0.307400  0.114600   4.826000   1.581000
# Abs Diff                   0.023600  0.010400   1.314000   0.819000
# % Diff                     7.129909  8.320000  21.400651  34.125000
# LogPDF                     1.204093  4.156235   0.114093 -15.642552
#
#                                pu241      pu242
# VAN-2|EF05|WZR0058|E58-88   1.130000   0.556000
# 43225                       0.938900   0.472900
# Abs Diff                    0.191100   0.083100
# % Diff                     16.911504  14.946043
# LogPDF                      0.123411   2.196960
