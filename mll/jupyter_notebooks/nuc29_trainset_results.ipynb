# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Data Setup & Functions

# %%
from mll_calc.mll_pred import format_XY

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

# %%
def loop_db(XY, pred, unc, lbls, nonlbls):  
    logpdf_df = pd.DataFrame()
    for idx, row in pred.iterrows():
        sim_idx = row['sim_idx']
        pred_idx = row['pred_idx']
        all_lbls = lbls + nonlbls
        
        test_sample = XY.loc[sim_idx].drop(all_lbls)
        train_row = XY.loc[pred_idx].drop(all_lbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = row['MaxLogLL']
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=sim_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %% [markdown]
# ### Train and Test DBs

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

train_pkl = '~/sims_n_results/final_sims_nov2020/not-scaled_nuc29.pkl'
XY = format_XY(train_pkl)

# %% [markdown]
# ### LL Calc Results

# %%
results = '~/sims_n_results/final_sims_nov2020/mll/train/'

uncs = [0.05, 0.1, 0.15, 0.2]
job_dirs = ['Job' + str(i) + '_unc' + str(unc) for i, unc in enumerate(uncs)]
dfs = {}
for i, unc_job in enumerate(job_dirs):
    dfs['unc' + str(i)] = pd.read_csv(results + unc_job + '/' + unc_job + '.csv')

for dfname in list(dfs.keys()):
    df = dfs[dfname]
    df['Relative_Burnup_Error'] = df['Burnup_Error'] / df['Burnup']
    df['Relative_Enrichment_Error'] = df['Enrichment_Error'] / df['Enrichment']
    df['Relative_CoolingTime_Error'] = df['CoolingTime_Error'] / df['CoolingTime']

# For ease of only viewing 5% case for now
preds = dfs['unc0']

# %%
preds.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'sim_idx', 'ReactorType', 'CoolingTime',
#        'Enrichment', 'Burnup', 'OrigenReactor', 'AvgPowerDensity',
#        'ModDensity', 'UiWeight', 'pred_idx', 'pred_ReactorType',
#        'pred_CoolingTime', 'pred_Enrichment', 'pred_Burnup',
#        'pred_OrigenReactor', 'pred_AvgPowerDensity', 'pred_ModDensity',
#        'pred_UiWeight', 'MaxLogLL', 'MaxLLUnc', '2ndMaxLogLL', '2ndMaxLLUnc',
#        'CDF_LogLL_0.9998', 'CDF_LLUnc_0.9998', 'CDF_LogLL_0.9988',
#        'CDF_LLUnc_0.9988', 'CDF_LogLL_0.95', 'CDF_LLUnc_0.95', 'CDF_LogLL_0.9',
#        'CDF_LLUnc_0.9', 'CDF_LogLL_0.5', 'CDF_LLUnc_0.5', 'CDF_LogLL_0.1',
#        'CDF_LLUnc_0.1', 'CDF_LogLL_0.01', 'CDF_LLUnc_0.01',
#        'ReactorType_Score', 'CoolingTime_Error', 'Enrichment_Error',
#        'Burnup_Error', 'OrigenReactor_Score', 'Relative_Burnup_Error',
#        'Relative_Enrichment_Error', 'Relative_CoolingTime_Error'],
#       dtype='object')

# %% [markdown]
# ### LogPDF (wrt nuclide) results

# %%
unc = 0.05
logpdf_df = loop_db(XY, preds, unc, lbls, nonlbls)

# %% [markdown]
# # Explore Errors

# %% [markdown]
# ### Burnup

# %%
preds['Relative_Burnup_Error'].describe()
# old nuc29 results for comparison
#count    12000.000000
#mean         0.003525
#std          0.009948
#min          0.000000
#25%          0.000000
#50%          0.000000
#75%          0.000000
#max          0.149049
# Out:
# count    24030.000000
# mean         0.003469
# std          0.009906
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.141558
# Name: Relative_Burnup_Error, dtype: float64

# %%
to_print = ['sim_idx', 'pred_idx', 'MaxLogLL',
            'AvgPowerDensity', 'pred_AvgPowerDensity', 
            'ModDensity', 'pred_ModDensity',
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Relative_Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Relative_Burnup_Error',
            'CoolingTime', 'pred_CoolingTime', 'Relative_CoolingTime_Error',
            'OrigenReactor', 'pred_OrigenReactor']
preds.loc[preds['Relative_Burnup_Error'] > 0.09, to_print]
# Out:
#        sim_idx  pred_idx    MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 3317     72845     76265 -110.207959             22.0                  22.0
# 3319     72846     76266 -109.265031             22.0                  22.0
# 7743    170473     73095 -122.380574             22.0                  22.0
# 10486   230661    331465  -90.425388             22.0                  22.0
# 10853   238749    141310 -101.410056             10.0                  10.0
# 11479   252435    255855 -101.808159             10.0                  10.0
# 11706   257409    260829  -93.406339             22.0                  22.0
# 11995   263950    163152  -67.038425             22.0                  22.0
# 16045   352931    258852  -50.870555             10.0                  10.0
# 23963   527289    522310  -64.300861             18.0                  22.0
#
#        ModDensity  pred_ModDensity ReactorType pred_ReactorType  \
# 3317         0.30             0.50         bwr              bwr
# 3319         0.30             0.50         bwr              bwr
# 7743         0.10             0.30         bwr              bwr
# 10486        0.70             0.70         bwr              bwr
# 10853        0.30             0.50         bwr              bwr
# 11479        0.10             0.30         bwr              bwr
# 11706        0.30             0.50         bwr              bwr
# 11995        0.70             0.70         bwr              bwr
# 16045        0.10             0.50         bwr              bwr
# 23963        0.84             0.84        phwr             phwr
#
#        ReactorType_Score  ...  pred_Enrichment  Relative_Enrichment_Error  \
# 3317                True  ...            3.830                   0.000000
# 3319                True  ...            3.830                   0.000000
# 7743                True  ...            3.830                   0.010554
# 10486               True  ...            1.450                   0.066176
# 10853               True  ...            1.960                   0.024876
# 11479               True  ...            2.890                   0.000000
# 11706               True  ...            2.890                   0.000000
# 11995               True  ...            3.270                   0.131488
# 16045               True  ...            2.890                   0.052459
# 23963               True  ...            0.711                   0.000000
#
#          Burnup  pred_Burnup  Relative_Burnup_Error  CoolingTime  \
# 3317   14183.67     15521.57               0.094327   123.964470
# 3319   14183.67     15521.57               0.094327   213.376227
# 7743   19194.08     20962.08               0.092112  1103.125238
# 10486  11220.14     12296.75               0.095953  1947.827214
# 10853   4156.59      4744.99               0.141558   564.091877
# 11479  10185.04     11220.14               0.101629  1344.264698
# 11706   9326.39     10185.04               0.092067   564.091877
# 11995   4156.59      4744.99               0.141558   698.651910
# 16045   2961.19      3235.81               0.092740   859.422117
# 23963   4169.04      4551.81               0.091813   591.580111
#
#        pred_CoolingTime  Relative_CoolingTime_Error  OrigenReactor  \
# 3317         123.964470                    0.000000        ge7x7-0
# 3319         213.376227                    0.000000        ge7x7-0
# 7743        1100.612018                    0.002278       abb8x8-1
# 10486       1960.053924                    0.006277  atrium10x10-9
# 10853        545.167126                    0.033549  atrium10x10-9
# 11479       1344.264698                    0.000000  atrium10x10-9
# 11706        564.091877                    0.000000  atrium10x10-9
# 11995        744.412322                    0.065498  atrium10x10-9
# 16045        854.168573                    0.006113       svea64-1
# 23963        570.998629                    0.034791        candu37
#
#       pred_OrigenReactor
# 3317             ge7x7-0
# 3319             ge7x7-0
# 7743             ge7x7-0
# 10486           svea64-1
# 10853           abb8x8-1
# 11479      atrium10x10-9
# 11706      atrium10x10-9
# 11995           abb8x8-1
# 16045      atrium10x10-9
# 23963            candu19
#
# [10 rows x 21 columns]

# %%
# finding a good prediction with high Max LL
new_df = preds.loc[(preds['Relative_Burnup_Error'] == 0.0) & 
                   (preds['Relative_Enrichment_Error'] == 0.0) & 
                   (preds['Relative_CoolingTime_Error'] == 0.0) & 
                   (preds['ReactorType_Score'] == True) &
                   (preds['MaxLogLL'] > 20), to_print]
new_df
# Out:
#        sim_idx  pred_idx   MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 21361   470037    468777  34.354942             41.0                  35.0
# 23198   510319    511579  27.584170             35.0                  41.0
#
#        ModDensity  pred_ModDensity ReactorType pred_ReactorType  \
# 21361        0.71             0.71         pwr              pwr
# 23198        0.71             0.71         pwr              pwr
#
#        ReactorType_Score  ...  pred_Enrichment  Relative_Enrichment_Error  \
# 21361               True  ...             5.40                        0.0
# 23198               True  ...             4.36                        0.0
#
#         Burnup  pred_Burnup  Relative_Burnup_Error  CoolingTime  \
# 21361  1878.95      1878.95                    0.0  6878.110557
# 23198  1817.43      1817.43                    0.0  1360.851082
#
#        pred_CoolingTime  Relative_CoolingTime_Error  OrigenReactor  \
# 21361       6878.110557                         0.0         s18x18
# 23198       1360.851082                         0.0       vver1000
#
#       pred_OrigenReactor
# 21361             s18x18
# 23198           vver1000
#
# [2 rows x 21 columns]

# %%
new_df.iloc[0:1].to_pickle('train_pred_good.pkl')

# %%
# finding a bad prediction
new_df = preds.loc[(preds['Relative_Burnup_Error'] > 0.05) & 
                   (preds['Relative_Enrichment_Error'] > 0.05) & 
                   (preds['Relative_CoolingTime_Error'] != np.inf) & (preds['Relative_CoolingTime_Error'] > 0.05) &
                   (preds['ReactorType_Score'] == False), to_print]
                   #(preds['MaxLogLL'] > 20)
new_df
# Out:
#        sim_idx  pred_idx    MaxLogLL  AvgPowerDensity  pred_AvgPowerDensity  \
# 10476   230410    452471  -68.234490             22.0                  25.0
# 21259   467584    294244  -57.322216             25.0                  22.0
# 21612   475627    123607 -120.117251             25.0                  22.0
#
#        ModDensity  pred_ModDensity ReactorType pred_ReactorType  \
# 10476        0.70             0.71         bwr              pwr
# 21259        0.71             0.50         pwr              bwr
# 21612        0.71             0.30         pwr              bwr
#
#        ReactorType_Score  ...  pred_Enrichment  Relative_Enrichment_Error  \
# 10476              False  ...             1.51                   0.110294
# 21259              False  ...             4.97                   0.079630
# 21612              False  ...             1.47                   0.063694
#
#          Burnup  pred_Burnup  Relative_Burnup_Error  CoolingTime  \
# 10476   6085.43      6409.86               0.053313   698.651910
# 21259   6409.86      6085.43               0.050614    35.352356
# 21612  28775.72     27118.57               0.057588   291.648122
#
#        pred_CoolingTime  Relative_CoolingTime_Error  OrigenReactor  \
# 10476        648.505877                    0.071775  atrium10x10-9
# 21259         27.895076                    0.210942         s18x18
# 21612        317.650622                    0.089157        bw15x15
#
#       pred_OrigenReactor
# 10476             s18x18
# 21259      atrium10x10-9
# 21612           abb8x8-1
#
# [3 rows x 21 columns]

# %%
new_df.iloc[0:1].to_pickle('train_pred_bad.pkl')

# %% [markdown]
# ### Enrichment

# %%
preds['Relative_Enrichment_Error'].describe()
# old nuc29 results for comparison
#count    12000.000000
#mean         0.003752
#std          0.014869
#min          0.000000
#25%          0.000000
#50%          0.000000
#75%          0.000000
#max          0.248447
# Out:
# count    24030.000000
# mean         0.003688
# std          0.015824
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.260204
# Name: Relative_Enrichment_Error, dtype: float64

# %%
preds.loc[preds['Relative_Enrichment_Error'] > 0.17, to_print]
# Out:
#        sim_idx  pred_idx  AvgPowerDensity ReactorType pred_ReactorType  \
# 6193    136267    321067             22.0         bwr              bwr
# 7003    154153     70155             22.0         bwr              bwr
# 9968    219250     17711             10.0         bwr              bwr
# 9973    219494     17894             10.0         bwr              bwr
# 10018   220335     18736             22.0         bwr              bwr
# 10032   220761     19221             22.0         bwr              bwr
# 10132   222861     21260             10.0         bwr              bwr
# 10232   225082     23482             22.0         bwr              bwr
# 10301   226750     25150             10.0         bwr              bwr
# 16730   368105     82505             22.0         bwr              bwr
# 19018   418438    463797             25.0         pwr              pwr
# 23532   517804    504004             32.0         pwr              pwr
# 23534   517863    483903             32.0         pwr              pwr
# 23708   521583    519003             32.0         pwr              pwr
#
#        ReactorType_Score  Enrichment  pred_Enrichment  \
# 6193                True        1.96             1.45
# 7003                True        3.27             3.83
#std               NaN
#min      0.000000e+00
#25%      3.333665e-03
#50%      1.209631e-02
#75%      2.999413e-02
#max               inf
# Out:
# count    2.402900e+04
# mean              inf
# std               NaN
# min      0.000000e+00
# 25%      3.174909e-03
# 50%      1.037382e-02
# 75%      2.831056e-02
# max               inf
# Name: Relative_CoolingTime_Error, dtype: float64

# %%
preds.loc[(preds['Relative_CoolingTime_Error'] != np.inf) & (preds['Relative_CoolingTime_Error'] > 3.3), to_print]
# Out:
#        sim_idx  pred_idx  AvgPowerDensity ReactorType pred_ReactorType  \
# 19624   431823    431824             35.0         pwr              pwr
# 20173   443943    443944             41.0         pwr              pwr
# 20831   458343    458344             35.0         pwr              pwr
# 20947   460743    460744             25.0         pwr              pwr
# 20950   460983    460984             25.0         pwr              pwr
# 23656   520365    520366             32.0         pwr              pwr
# 23792   523504    523505             22.0        phwr             phwr
# 23990   527823    527824             18.0        phwr             phwr
#
#        ReactorType_Score  Enrichment  pred_Enrichment  \
# 19624               True       1.630            1.630
# 20173               True       3.860            3.860
# 20831               True       1.900            1.900
# 20947               True       3.000            3.000
# 20950               True       3.000            3.000
# 23656               True       3.820            3.820
# 23792               True       0.711            0.711
# 23990               True       0.711            0.711
#
#        Relative_Enrichment_Error    Burnup  pred_Burnup  \
# 19624                        0.0  45569.93     45569.93
# 20173                        0.0  20332.54     20332.54
# 20831                        0.0  54038.26     54038.26
# 20947                        0.0  41813.04     41813.04
# 20950                        0.0  62060.12     62060.12
# 23656                        0.0  55107.98     55107.98
# 23792                        0.0    976.14       976.14
# 23990                        0.0   8359.44      8359.44
#
#        Relative_Burnup_Error  CoolingTime  pred_CoolingTime  \
# 19624                    0.0     5.378912         33.379722
# 20173                    0.0     5.378912         33.379722
# 20831                    0.0     5.822302         35.352356
# 20947                    0.0     5.822302         35.352356
# 20950                    0.0     5.822302         35.352356
# 23656                    0.0     5.853899         27.174611
# 23792                    0.0    21.245189        118.534143
# 23990                    0.0     6.087128         30.272394
#
#        Relative_CoolingTime_Error OrigenReactor pred_OrigenReactor    MaxLogLL
# 19624                    5.205664        w17x17             w17x17 -116.848470
# 20173                    5.205664        w17x17             w17x17  -97.554395
# 20831                    5.071886        s18x18             s18x18 -120.535317
# 20947                    5.071886        s18x18             s18x18 -116.226126
# 20950                    5.071886        s18x18             s18x18 -123.569189
# 23656                    3.642139  vver440_3.82       vver440_3.82 -120.891197
# 23792                    4.579340       candu28            candu28 -314.132343
# 23990                    3.973182       candu37            candu37  -65.743391

# %% [markdown]
# # Max Log LL

# %%
print(dfs['unc0']['MaxLogLL'].describe())
print(dfs['unc3']['MaxLogLL'].describe())
# Out:
# count    24030.000000
# mean       -72.590698
# std         39.836912
# min       -314.132343
# 25%       -100.163817
# 50%        -84.816623
# 75%        -57.545144
# max         99.408788
# Name: MaxLogLL, dtype: float64
# count    24030.000000
# mean      -109.490204
# std         40.547331
# 121355 -2.277091  0.512247 -1.672240 -3.584777 -6.866712 -5.139916 -11.714527
# 15788  -2.835861  0.721421 -2.289992 -3.298485 -4.374940 -4.460333 -11.715448
# 160682 -3.621641 -0.268926 -2.629126 -3.269837 -6.889690 -6.247057 -11.681300
# 366094 -4.160554 -0.297875 -2.954298 -2.979590 -4.617524 -6.192707 -11.655118
# 388273 -1.342244  0.005132 -0.524413 -3.739126 -8.593091 -5.020755 -11.685843
#
# [10 rows x 29 columns]

# %%
for nuc in nuc29:
    desc = logpdf_df[nuc].describe()
    print(desc[['mean', 'std', 'min', 'max']])
# Out:
# mean     -2.820982
# std       2.145106
# min    -107.827192
# max       9.930513
# Name: am241, dtype: float64
# mean     3.857434
# std      3.062783
# min    -51.241867
# max     17.370122
# Name: am242m, dtype: float64
# mean    -0.688843
# std      4.058155
# min     -8.728945
# max     15.104302
# Name: am243, dtype: float64
# mean      6.749372
# std       5.590586
# min    -113.053963
# max      23.318809
# Name: cm242, dtype: float64
# mean     1.097483
# std      5.366312
# min    -22.510467
# max     21.060062
# Name: cm244, dtype: float64
# mean     0.425326
# std      2.690959
# min    -28.348369
# max     10.668878
# Name: cs134, dtype: float64
# mean   -4.267991
# std     1.022022
# min    -6.442801
# max    -0.337778
# Name: cs137, dtype: float64
# mean    0.642084
# std     1.875193
# min    -2.957553
# max     8.037416
# Name: eu154, dtype: float64
# mean   -3.972439
# std     0.797334
# min    -6.405137
# max    -0.669194
# Name: nd143, dtype: float64
# mean    -4.476833
# std      1.279887
# min    -72.752913
# max      1.471931
# Name: nd144, dtype: float64
# mean   -3.864442
# std     0.930404
# min    -6.256030
# max    -0.278384
# Name: nd145, dtype: float64
# mean   -3.877736
# std     1.096123
# min    -6.805930
# max    -0.030020
# Name: nd146, dtype: float64
# mean   -3.269151
# std     1.039270
# min    -5.585647
# max     0.512144
# Name: nd148, dtype: float64
# mean   -2.539068
# std     1.110664
# min    -4.834355
# max     1.407939
# Name: nd150, dtype: float64
# mean   -3.043218
# std     1.309072
# min    -8.099542
# max     2.119910
# Name: np237, dtype: float64
# mean   -1.716264
# std     2.424611
# min    -7.726147
# max     7.488688
# Name: pu238, dtype: float64
# mean   -6.032002
# std     0.489808
# min    -9.704031
# max    -3.696515
# Name: pu239, dtype: float64
# mean   -4.554003
# std     1.040217
# min    -8.017968
# max     0.564087
# Name: pu240, dtype: float64
# mean   -3.783585
# std     1.733648
# min    -8.995306
# max     4.538505
# Name: pu241, dtype: float64
# mean    -2.920005
# std      2.938573
# min    -11.241115
# max      9.177770
# Name: pu242, dtype: float64
# mean     -2.750205
# std       1.221648
# min    -113.829205
# max       4.597037
# Name: sm147, dtype: float64
# mean     1.156759
# std      0.677570
# min    -12.161403
# max      3.242105
# Name: sm149, dtype: float64
# mean   -2.933678
# std     1.102158
# min    -7.034992
# max     1.127842
# Name: sm150, dtype: float64
# mean    0.033077
# std     0.595427
# min    -8.990780
# max     2.446280
# Name: sm151, dtype: float64
# mean   -2.072472
# std     0.948775
# min    -6.271497
# max     1.821377
# Name: sm152, dtype: float64
# mean   -3.346419
# std     0.365286
# min    -4.225140
# max    -1.628451
# Name: u234, dtype: float64
# mean    -6.457593
# std      1.939919
# min    -42.041173
# max     -0.379370
# Name: u235, dtype: float64
# mean    -5.477517
# std      0.839256
# min    -12.750781
# max     -2.208447
# Name: u236, dtype: float64
# mean   -11.687788
# std      0.021967
# min    -11.731793
# max    -11.630352
# Name: u238, dtype: float64

# %%
arr = []
for nuc in nuc29:
    desc = logpdf_df[nuc].describe()
    arr.append((desc['mean'], desc['std'], desc['min'], desc['max']))
logpdf_nuc = pd.DataFrame(arr, index=nuc29, columns=['mean', 'std', 'min', 'max'])

# %%
logpdf_nuc
# Out:
#              mean       std         min        max
# am241   -2.820982  2.145106 -107.827192   9.930513
# am242m   3.857434  3.062783  -51.241867  17.370122
# am243   -0.688843  4.058155   -8.728945  15.104302
# cm242    6.749372  5.590586 -113.053963  23.318809
# cm244    1.097483  5.366312  -22.510467  21.060062
# cs134    0.425326  2.690959  -28.348369  10.668878
# cs137   -4.267991  1.022022   -6.442801  -0.337778
# eu154    0.642084  1.875193   -2.957553   8.037416
# nd143   -3.972439  0.797334   -6.405137  -0.669194
# nd144   -4.476833  1.279887  -72.752913   1.471931
# nd145   -3.864442  0.930404   -6.256030  -0.278384
# nd146   -3.877736  1.096123   -6.805930  -0.030020
# nd148   -3.269151  1.039270   -5.585647   0.512144
# nd150   -2.539068  1.110664   -4.834355   1.407939
# np237   -3.043218  1.309072   -8.099542   2.119910
# pu238   -1.716264  2.424611   -7.726147   7.488688
# pu239   -6.032002  0.489808   -9.704031  -3.696515
# pu240   -4.554003  1.040217   -8.017968   0.564087
# pu241   -3.783585  1.733648   -8.995306   4.538505
# pu242   -2.920005  2.938573  -11.241115   9.177770
# sm147   -2.750205  1.221648 -113.829205   4.597037
# sm149    1.156759  0.677570  -12.161403   3.242105
# sm150   -2.933678  1.102158   -7.034992   1.127842
# sm151    0.033077  0.595427   -8.990780   2.446280
# sm152   -2.072472  0.948775   -6.271497   1.821377
# u234    -3.346419  0.365286   -4.225140  -1.628451
# u235    -6.457593  1.939919  -42.041173  -0.379370
# u236    -5.477517  0.839256  -12.750781  -2.208447
# u238   -11.687788  0.021967  -11.731793 -11.630352

# %%
logpdf_nuc['mean'].nlargest(7)
# Out:
# cm242     6.749372
# am242m    3.857434
# sm149     1.156759
# cm244     1.097483
# eu154     0.642084
# cs134     0.425326
# sm151     0.033077
# Name: mean, dtype: float64

# %%
logpdf_nuc['max'].nlargest(7)
# Out:
# cm242     23.318809
# cm244     21.060062
# am242m    17.370122
# am243     15.104302
# cs134     10.668878
# am241      9.930513
# pu242      9.177770
# Name: max, dtype: float64
