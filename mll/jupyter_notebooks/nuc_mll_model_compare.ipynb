# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
from mll_calc.mll_pred import format_XY

# %%
def logpdf_calc(row, test_sample, unc):
    y_sim = row[test_sample>0].values.tolist()
    std = row.multiply(unc)[test_sample>0].values.tolist()
    y_mes = test_sample[test_sample>0].values.tolist()
    logpdf_list = stats.norm.logpdf(y_sim, loc=y_mes, scale=std)
    return logpdf_list

def loop_db(XY, pred, unc, lbls, nonlbls):
    logpdf_df = pd.DataFrame()
    for idx, row in pred.iterrows():
        sim_idx = row['sim_idx']
        pred_idx = row['pred_idx']
        all_lbls = lbls + nonlbls
        
        test_sample = XY.loc[sim_idx].drop(all_lbls)
        train_row = XY.loc[pred_idx].drop(all_lbls)
        
        logpdf = logpdf_calc(train_row, test_sample, unc)
        mll = row['MaxLogLL']
        
        if round(mll, 4) != round(np.sum(logpdf), 4):
            print('mismatch')
            break
        
        logpdf = pd.Series(logpdf, index=train_row[test_sample>0].index, name=sim_idx)
        if logpdf_df.empty:
            logpdf_df = pd.DataFrame(columns = test_sample.index.to_list())
        logpdf_df = logpdf_df.append(logpdf)
    return logpdf_df

# %%
lbls = ['ReactorType', 'CoolingTime', 'Enrichment', 'Burnup', 'OrigenReactor']
nonlbls = ['AvgPowerDensity', 'ModDensity', 'UiWeight']

train15_pkl = '~/sims_n_results/simupdates_aug2020/not-scaled_nuc15.pkl'
XY15 = format_XY(train15_pkl)

train29_pkl = '~/sims_n_results/simupdates_aug2020/not-scaled_nuc15.pkl'
XY29 = format_XY(train29_pkl)

# %%
results15 = '~/sims_n_results/simupdates_aug2020/train15/'
results29 = '~/sims_n_results/simupdates_aug2020/train15/'

uncs = [0.05, ]#0.1, 0.15, 0.2]
job_dirs = ['Job' + str(i) + '_unc' + str(unc) for i, unc in enumerate(uncs)]
dfs = {}
for i, unc_job in enumerate(job_dirs):
    preds15 = pd.read_csv(results15 + unc_job + '/' + unc_job + '.csv')
    preds29 = pd.read_csv(results29 + unc_job + '/' + unc_job + '.csv')

# %%
# overlapping predictions in both sets
to_print = ['sim_idx', 'pred_idx', 'AvgPowerDensity', 
            'ReactorType', 'pred_ReactorType', 'ReactorType_Score', 
            'Enrichment', 'pred_Enrichment', 'Enrichment_Error', 
            'Burnup', 'pred_Burnup', 'Burnup_Error',
            'CoolingTime', 'pred_CoolingTime', 'CoolingTime_Error',
            'OrigenReactor', 'pred_OrigenReactor', 'MaxLogLL']
preds15 = preds15.loc[:, to_print]
preds29 = preds29.loc[:, to_print]

preds = preds15.join(preds29, on = 'sim_idx', how = 'inner', lsuffix = '_l', rsuffix = '_r')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
preds.sample(20)
# Out:
#      sim_idx  sim_idx_l  pred_idx_l  AvgPowerDensity_l ReactorType_l  \
# 24      1029       1029        1028               10.0           bwr
# 177     6732       6732        6733               20.0           bwr
# 43      1584       1584        1585               10.0           bwr
# 168     6435       6435        6375               10.0           bwr
# 247     9448       9448        9449               25.0           bwr
# 78      3053       3053        3054               20.0           bwr
# 197     7576       7576        7577               20.0           bwr
# 189     7299       7299       67779               20.0           bwr
# 128     4946       4946        4947               25.0           bwr
# 159     5979       5979      187362               10.0           bwr
# 41      1640       1640       62118               10.0           bwr
# 198     7614       7614        7613               20.0           bwr
# 4        261        261         262               10.0           bwr
# 40      1534       1534        1533               10.0           bwr
# 232     8994       8994        8993               25.0           bwr
# 1        116        116        5156               10.0           bwr
# 190     7289       7289        7288               20.0           bwr
# 158     6033       6033        6034               10.0           bwr
# 191     7342       7342        7341               20.0           bwr
# 55      2126       2126        2127               20.0           bwr
#
#     pred_ReactorType_l  ReactorType_Score_l  Enrichment_l  pred_Enrichment_l  \
# 24                 bwr                 True           0.5               0.50
# 177                bwr                 True           0.5               0.50
# 43                 bwr                 True           0.5               0.50
# 168                bwr                 True           0.5               0.50
# 247                bwr                 True           0.5               0.50
# 78                 bwr                 True           0.5               0.50
# 197                bwr                 True           0.5               0.50
# 189                bwr                 True           0.5               0.55
# 128                bwr                 True           0.5               0.50
# 159                bwr                 True           0.5               0.50
# 41                 bwr                 True           0.5               0.55
# 198                bwr                 True           0.5               0.50
# 4                  bwr                 True           0.5               0.50
# 40                 bwr                 True           0.5               0.50
# 232                bwr                 True           0.5               0.50
# 1                  bwr                 True           0.5               0.50
# 190                bwr                 True           0.5               0.50
# 158                bwr                 True           0.5               0.50
# 191                bwr                 True           0.5               0.50
# 55                 bwr                 True           0.5               0.50
#
#      Enrichment_Error_l  Burnup_l  pred_Burnup_l  Burnup_Error_l  \
# 24                 0.00  30660.96       30660.96            0.00
# 177                0.00    965.63         965.63            0.00
# 43                 0.00  63534.57       63534.57            0.00
# 168                0.00  48949.30       48334.78          614.52
# 247                0.00  30660.96       30660.96            0.00
# 78                 0.00  48334.78       48334.78            0.00
# 197                0.00  21745.58       21745.58            0.00
# 189                0.05  13478.85       13558.75           79.90
# 128                0.00  63534.57       63534.57            0.00
# 159                0.00  22690.61       22475.28          215.33
# 41                 0.05  70500.00       70500.00            0.00
# 198                0.00  21745.58       21745.58            0.00
# 4                  0.00   6261.29        6261.29            0.00
# 40                 0.00  60654.19       60654.19            0.00
# 232                0.00  13478.85       13478.85            0.00
# 1                  0.00   1979.95        1979.95            0.00
# 190                0.00  13478.85       13478.85            0.00
# 158                0.00  29424.92       29424.92            0.00
# 191                0.00  16053.83       16053.83            0.00
# 55                 0.00  10686.23       10686.23            0.00
#
#      CoolingTime_l  pred_CoolingTime_l  CoolingTime_Error_l OrigenReactor_l  \
# 24      473.850856          471.388214             2.462642         ge7x7-0
# 177    1032.998451         1046.132758            13.134307         ge7x7-0
# 43     2074.891758         2079.301841             4.410083         ge7x7-0
# 168    1206.810070         1206.810070             0.000000         ge7x7-0
# 247    2598.806600         2625.070937            26.264337         ge7x7-0
# 78     5128.931533         5158.023377            29.091844         ge7x7-0
# 197    1250.512881         1272.233919            21.721038         ge7x7-0
# 189    3828.695214         3869.273243            40.578029         ge7x7-0
# 128    2311.579113         2355.494784            43.915671         ge7x7-0
# 159    3828.695214         3758.522130            70.173084         ge7x7-0
# 41     1520.464582         1478.591369            41.873213         ge7x7-0
# 198    5158.023377         5128.931533            29.091844         ge7x7-0
# 4      1875.921048         1891.859980            15.938932         ge7x7-0
# 40     3258.107022         3215.497041            42.609981         ge7x7-0
# 232    5158.023377         5128.931533            29.091844         ge7x7-0
# 1      5936.192301         5936.192301             0.000000         ge7x7-0
# 190    2625.070937         2598.806600            26.264337         ge7x7-0
# 158    3215.497041         3258.107022            42.609981         ge7x7-0
# 191    1891.859980         1875.921048            15.938932         ge7x7-0
# 55     2311.579113         2355.494784            43.915671         ge7x7-0
#
#     pred_OrigenReactor_l  MaxLogLL_l  sim_idx_r  pred_idx_r  \
# 24               ge7x7-0  -50.838399      39417      220856
# 177              ge7x7-0    9.162696     257530      257531
# 43               ge7x7-0  -56.287381      60724       60723
# 168              ge7x7-0  -54.629971     246110      246170
# 247              ge7x7-0  -47.992152     361436      361437
# 78               ge7x7-0  -50.135744     116814      116815
# 197              ge7x7-0  -45.368293     289817      289816
# 189             abb8x8-1  -36.641836     279128      279068
# 128              ge7x7-0  -56.980939     189180      189239
# 159             svea64-1  -44.299913     228610      228609
# 41              abb8x8-1  -58.694869      62816       62815
# 198              ge7x7-0  -40.290491     291272      291273
# 4                ge7x7-0  -26.373749       9951        9950
# 40               ge7x7-0  -54.682785      58621       58622
# 232              ge7x7-0  -33.630041     344086      344087
# 1                ge7x7-0   -5.061042       4554        4553
# 190              ge7x7-0  -36.979659     278871      278870
# 158              ge7x7-0  -46.588472     230811      230812
# 191              ge7x7-0  -40.380867     280891      348930
# 55               ge7x7-0  -34.431008      81353       81352
#
#      AvgPowerDensity_r ReactorType_r pred_ReactorType_r  ReactorType_Score_r  \
# 24                25.0           bwr                bwr                 True
# 177               25.0           pwr                pwr                 True
# 43                10.0           bwr                bwr                 True
# 168               25.0           pwr                pwr                 True
# 247               22.0          phwr               phwr                 True
# 78                10.0           bwr                bwr                 True
# 197               41.0           pwr                pwr                 True
# 189               41.0           pwr                pwr                 True
# 128               20.0           bwr                bwr                 True
# 159               20.0           bwr                bwr                 True
# 41                20.0           bwr                bwr                 True
# 198               25.0           pwr                pwr                 True
# 4                 25.0           bwr                bwr                 True
# 40                20.0           bwr                bwr                 True
# 232               25.0           pwr                pwr                 True
# 1                 25.0           bwr                bwr                 True
# 190               41.0           pwr                pwr                 True
# 158               25.0           bwr                bwr                 True
# 191               25.0           pwr                pwr                 True
# 55                10.0           bwr                bwr                 True
#
#      Enrichment_r  pred_Enrichment_r  Enrichment_Error_r  Burnup_r  \
# 24          2.740              2.730                0.01  17668.74
# 177         3.760              3.760                0.00  23261.53
# 43          0.550              0.550                0.00   5533.40
# 168         1.520              1.520                0.00  19111.96
# 247         0.711              0.711                0.00   7263.40
# 78          5.230              5.230                0.00  21800.82
# 197         0.500              0.500                0.00   1967.36
# 189         2.920              2.920                0.00  30039.95
# 128         0.500              0.500                0.00  30045.06
# 159         4.070              4.070                0.00   2796.41
# 41          0.550              0.550                0.00  14269.34
# 198         1.480              1.480                0.00   8191.31
# 4           0.500              0.500                0.00  60654.19
# 40          4.570              4.570                0.00  60654.19
# 232         3.040              3.040                0.00   3763.56
# 1           0.500              0.500                0.00  34140.74
# 190         2.920              2.920                0.00  19195.69
# 158         4.070              4.070                0.00  15572.83
# 191         3.820              4.030                0.21  61271.92
# 55          2.080              2.080                0.00  16253.99
#
#      pred_Burnup_r  Burnup_Error_r  CoolingTime_r  pred_CoolingTime_r  \
# 24        18096.51          427.77    6160.818841         6159.232422
# 177       23261.53            0.00     750.085316          848.060234
# 43         5533.40            0.00      27.412098            7.797336
# 168       19775.13          663.17    5333.959300         5333.959300
# 247        7263.40            0.00    6483.944237         6678.915522
# 78        21800.82            0.00    6026.246281         6103.568798
# 197        1967.36            0.00    1397.952960         1351.325953
# 189       29851.60          188.35     455.237804          455.237804
# 128       30045.06            0.00       0.000619            0.000000
# 159        2796.41            0.00     565.158549          523.199045
# 41        14269.34            0.00    6183.051962         6103.568798
# 198        8191.31            0.00    3277.462304         3285.947595
# 4         60654.19            0.00    4910.722126         4901.698528
# 40        60654.19            0.00       0.504127            0.826167
# 232        3763.56            0.00    4653.711229         4828.721146
# 1         34140.74            0.00    5158.023377         5128.931533
# 190       19195.69            0.00    5592.629810         5566.803051
# 158       15572.83            0.00    5168.906785         5189.716802
# 191       62676.49         1404.57    2943.035199         2949.732384
# 55        16253.99            0.00    5872.378989         5772.332872
#
#      CoolingTime_Error_r OrigenReactor_r pred_OrigenReactor_r  MaxLogLL_r
# 24              1.586419         ge7x7-0             svea64-1  -35.197104
# 177            97.974918         ce14x14              ce14x14  -47.250258
# 43             19.614762        abb8x8-1             abb8x8-1  -26.370728
# 168             0.000000         ce14x14              ce14x14  -43.313419
# 247           194.971285         candu19              candu19  -27.004577
# 78             77.322517        abb8x8-1             abb8x8-1  -35.866421
# 197            46.627007          s18x18               s18x18   -6.608460
# 189             0.000000          w17x17               w17x17  -50.992094
# 128             0.000619        svea64-1             svea64-1  -50.090386
# 159            41.959504        svea64-1             svea64-1   -0.112459
# 41             79.483164        abb8x8-1             abb8x8-1  -34.200233
# 198             8.485291          s18x18               s18x18  -26.198093
# 4               9.023598         ge7x7-0              ge7x7-0  -52.380776
# 40              0.322040         ge7x7-0              ge7x7-0  -59.654566
# 232           175.009917        vver1000             vver1000  -10.473691
# 1              29.091844         ge7x7-0              ge7x7-0  -46.324208
# 190            25.826759          w17x17               w17x17  -36.605670
# 158            20.810017        svea64-1             svea64-1  -30.462810
# 191             6.697185          w17x17             vver1000  -59.501795
# 55            100.046117        abb8x8-1             abb8x8-1  -35.089945

# %%
to_print_2 = ['MaxLogLL_l', 'MaxLogLL_r', 'Burnup_Error_l', 'Burnup_Error_r', 
              'Enrichment_Error_l', 'Enrichment_Error_r', 
              'CoolingTime_Error_r', 'CoolingTime_Error_r']
preds.loc[:, to_print_2].sample(20)
# Out:
#      MaxLogLL_l  MaxLogLL_r  Burnup_Error_l  Burnup_Error_r  \
# 31   -46.267675  -44.812435             0.0            0.00
# 152  -44.104600  -35.870123             0.0            0.00
# 155  -45.248006  -46.236946             0.0            0.00
# 169  -52.039704  -52.976269             0.0            0.00
# 5    -27.242643  -54.171732             0.0            0.00
# 248  -50.738206  -28.710187             0.0            0.00
# 37   -55.499709  -26.323204             0.0            0.00
# 81   -52.069627  -14.127972             0.0            0.00
# 116  -46.324208  -43.718984             0.0            0.00
# 40   -54.682785  -59.654566             0.0            0.00
# 120  -55.161891  -32.363017             0.0            0.00
# 146  -34.835773   -1.590984             0.0            0.00
# 118  -52.880152  -24.216212             0.0            0.00
# 221   10.706392  -55.728786             0.0          676.24
# 84   -52.955181  -59.124812             0.0          730.62
# 178   13.742486  -39.503567             0.0            0.00
# 83   -56.362657  -59.382014             0.0          730.62
# 30   -47.532252  -60.789214             0.0            0.00
# 218  -56.345506  -31.589467             0.0            0.00
# 246  -44.308624  -13.371377           615.9            0.00
#
#      Enrichment_Error_l  Enrichment_Error_r  CoolingTime_Error_r  \
# 31                  0.0                 0.0            53.146807
# 152                 0.0                 0.0             3.454678
# 155                 0.0                 0.0            30.859317
# 169                 0.0                 0.0            38.884825
# 5                   0.0                 0.0            15.938932
# 248                 0.0                 0.0            40.605195
# 37                  0.0                 0.0            21.721038
# 81                  0.0                 0.0            49.744153
# 116                 0.0                 0.0            50.938446
# 40                  0.0                 0.0             0.322040
# 120                 0.0                 0.0            46.590980
# 146                 0.0                 0.0            30.859317
# 118                 0.0                 0.0            86.606589
# 221                 0.0                 0.0             0.000000
# 84                  0.0                 0.0             0.000000
# 178                 0.0                 0.0            23.072130
# 83                  0.0                 0.0             0.000000
# 30                  0.0                 0.0            19.094961
# 218                 0.0                 0.0             0.000527
# 246                 0.0                 0.0            46.541245
#
#      CoolingTime_Error_r
# 31             53.146807
# 152             3.454678
# 155            30.859317
# 169            38.884825
# 5              15.938932
# 248            40.605195
# 37             21.721038
# 81             49.744153
# 116            50.938446
# 40              0.322040
# 120            46.590980
# 146            30.859317
# 118            86.606589
# 221             0.000000
# 84              0.000000
# 178            23.072130
# 83              0.000000
# 30             19.094961
# 218             0.000527
# 246            46.541245

# %%
#preds15
preds['MaxLogLL_l'].describe()
# Out:
# count    251.000000
# mean     -38.513872
# std       16.269817
# min      -60.082480
# 25%      -50.470185
# 50%      -42.287828
# 75%      -31.687015
# max       13.742486
# Name: MaxLogLL_l, dtype: float64

# %%
#preds29
preds['MaxLogLL_r'].describe()
# Out:
# count    251.000000
# mean     -38.129809
# std       18.475049
# min      -62.220978
# 25%      -51.340667
# 50%      -43.174071
# 75%      -30.749305
# max       26.853743
# Name: MaxLogLL_r, dtype: float64

# %%
unc = 0.05
logpdf15 = loop_db(XY15, preds15, unc, lbls, nonlbls)
logpdf29 = loop_db(XY29, preds29, unc, lbls, nonlbls)
